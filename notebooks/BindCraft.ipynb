# %% [markdown]
# # BindCraft: Protein binder design
#
# <img src="https://github.com/martinpacesa/BindCraft/blob/main/pipeline.png?raw=true">
#
# Simple binder design pipeline using AlphaFold2 backpropagation, MPNN, and PyRosetta. Select your target and let the script do the rest of the work and finish once you have enough designs to order!
#
# The designs will be saved on your Google Drive under BindCraft/[design_name]/ and you can continue running the design pipeline if the session times out and it will continue adding new designs.

# %%
#@title Installation
# %%time
import os, time, gc, io
import contextlib
import json
from datetime import datetime
from ipywidgets import HTML, VBox
from IPython.display import display

if not os.path.isfile("bindcraft/params/done.txt"):
  print("Installing required BindCraft components")

  print("Pulling BindCraft code from Github")
  os.makedirs('/content/bindcraft/', exist_ok=True)
  # !git clone https://github.com/martinpacesa/BindCraft /content/bindcraft/
  os.system("chmod +x /content/bindcraft/functions/dssp")
  os.system("chmod +x /content/bindcraft/functions/DAlphaBall.gcc")

  print("Installing ColabDesign")
  os.system("(mkdir bindcraft/params; apt-get install aria2 -qq; \
  aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar; \
  tar -xf alphafold_params_2022-12-06.tar -C bindcraft/params; touch bindcraft/params/done.txt )&")
  os.system("pip install git+https://github.com/sokrypton/ColabDesign.git")
  # for debugging purposes
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")

  print("Installing PyRosetta")
  os.system("pip install pyrosettacolabsetup")
  with contextlib.redirect_stdout(io.StringIO()):
    import pyrosettacolabsetup
    pyrosettacolabsetup.install_pyrosetta(serialization=True, cache_wheel_on_google_drive=False)

  # download params
  if not os.path.isfile("bindcraft/params/done.txt"):
    print("downloading AlphaFold params")
    while not os.path.isfile("bindcraft/params/done.txt"):
      time.sleep(5)

  print("BindCraft installation is finished, ready to run!")
else:
  print("BindCraft components already installed, ready to run!")

# %%
#@title Mount your Google Drive to save design results
from google.colab import drive
drive.mount('/content/drive')
currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Google drive mounted at: {currenttime}")

bindcraft_google_drive = '/content/drive/My Drive/BindCraft/'
os.makedirs(bindcraft_google_drive, exist_ok=True)
print("BindCraft folder successfully created in your drive!")

# %%
#@title Binder design settings
# @markdown ---
# @markdown Enter path where to save your designs. We recommend to save on Google drive so that you can continue generating at any time.
design_path = "/content/drive/MyDrive/BindCraft/PDL1/" # @param {"type":"string","placeholder":"/content/drive/MyDrive/BindCraft/PDL1/"}

# @markdown Enter the name that should be prefixed to your binders (generally target name).
binder_name = "PDL1" # @param {"type":"string","placeholder":"PDL1"}

# @markdown The path to the .pdb structure of your target. Can be an experimental or AlphaFold2 structure. We recommend trimming the structure to as small as needed, as the whole selected chains will be backpropagated through the network and can significantly increase running times.
starting_pdb = "/content/bindcraft/example/PDL1.pdb" # @param {"type":"string","placeholder":"/content/bindcraft/example/PDL1.pdb"}

# @markdown Which chains of your PDB to target? Can be one or multiple, in a comma-separated format. Other chains will be ignored during design.
chains = "A" # @param {"type":"string","placeholder":"A,C"}

# @markdown What positions to target in your protein of interest? For example `1,2-10` or chain specific `A1-10,B1-20` or entire chains `A`. If left blank, an appropriate site will be selected by the pipeline.
target_hotspot_residues = "" # @param {"type":"string","placeholder":""}

# @markdown What is the minimum and maximum size of binders you want to design? Pipeline will randomly sample different sizes between these values.
lengths = "70,150" # @param {"type":"string","placeholder":"70,150"}

# @markdown How many binder designs passing filters do you require?
number_of_final_designs = 100 # @param {"type":"integer","placeholder":"100"}
# @markdown ---
# @markdown Enter path on your Google drive (/content/drive/MyDrive/BindCraft/[binder_name].json) to previous target settings to continue design campaign. If left empty, it will use the settings above and generate a new settings json in your design output folder.
load_previous_target_settings = "" # @param {"type":"string","placeholder":""}
# @markdown ---

if load_previous_target_settings:
    target_settings_path = load_previous_target_settings
else:
    lengths = [int(x.strip()) for x in lengths.split(',') if len(lengths.split(',')) == 2]

    if len(lengths) != 2:
        raise ValueError("Incorrect specification of binder lengths.")

    settings = {
        "design_path": design_path,
        "binder_name": binder_name,
        "starting_pdb": starting_pdb,
        "chains": chains,
        "target_hotspot_residues": target_hotspot_residues,
        "lengths": lengths,
        "number_of_final_designs": number_of_final_designs
    }

    target_settings_path = os.path.join(design_path, binder_name+".json")
    os.makedirs(design_path, exist_ok=True)

    with open(target_settings_path, 'w') as f:
        json.dump(settings, f, indent=4)

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Binder design settings updated at: {currenttime}")
print(f"New .json file with target settings has been generated in: {target_settings_path}")

# %%
#@title Advanced settings
# @markdown ---
# @markdown Which binder design protocol to run? Default is recommended. "Beta-sheet" promotes the design of more beta sheeted proteins, but requires more sampling. "Peptide" is optimised for helical peptide binders.
design_protocol = "Default" # @param ["Default","Beta-sheet","Peptide"]
# @markdown What prediction protocol to use?. "Default" performs single sequence prediction of the binder. "HardTarget" uses initial guess to improve complex prediction for difficult targets, but might introduce some bias.
prediction_protocol = "Default" # @param ["Default","HardTarget"]
# @markdown What interface design method to use?. "AlphaFold2" is the default, interface is generated by AlphaFold2. "MPNN" uses soluble MPNN to optimise the interface.
interface_protocol = "AlphaFold2" # @param ["AlphaFold2","MPNN"]
# @markdown What target template protocol to use? "Default" allows for limited amount flexibility. "Masked" allows for greater target flexibility on both sidechain and backbone level.
template_protocol = "Default" # @param ["Default","Masked"]
# @markdown ---

if design_protocol == "Default":
    design_protocol_tag = "default_4stage_multimer"
elif design_protocol == "Beta-sheet":
    design_protocol_tag = "betasheet_4stage_multimer"
elif design_protocol == "Peptide":
    design_protocol_tag = "peptide_3stage_multimer"
else:
    raise ValueError(f"Unsupported design protocol")

if interface_protocol == "AlphaFold2":
    interface_protocol_tag = ""
elif interface_protocol == "MPNN":
    interface_protocol_tag = "_mpnn"
else:
    raise ValueError(f"Unsupported interface protocol")

if template_protocol == "Default":
    template_protocol_tag = ""
elif template_protocol == "Masked":
    template_protocol_tag = "_flexible"
else:
    raise ValueError(f"Unsupported template protocol")

if design_protocol in ["Peptide"]:
    prediction_protocol_tag = ""
else:
    if prediction_protocol == "Default":
        prediction_protocol_tag = ""
    elif prediction_protocol == "HardTarget":
        prediction_protocol_tag = "_hardtarget"
    else:
        raise ValueError(f"Unsupported prediction protocol")

advanced_settings_path = "/content/bindcraft/settings_advanced/" + design_protocol_tag + interface_protocol_tag + template_protocol_tag + prediction_protocol_tag + ".json"

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Advanced design settings updated at: {currenttime}")

# %%
#@title Filters
# @markdown ---
# @markdown Which filters for designs to use? "Default" are recommended, "Peptide" are for the design of peptide binders, "Relaxed" are more permissive but may result in fewer experimental successes, "Peptide_Relaxed" are more permissive filters for non-helical peptides, "None" is for benchmarking.
filter_option = "Default" # @param ["Default", "Peptide", "Relaxed", "Peptide_Relaxed", "None"]
# @markdown ---

if filter_option == "Default":
    filter_settings_path = "/content/bindcraft/settings_filters/default_filters.json"
elif filter_option == "Peptide":
    filter_settings_path = "/content/bindcraft/settings_filters/peptide_filters.json"
elif filter_option == "Relaxed":
    filter_settings_path = "/content/bindcraft/settings_filters/relaxed_filters.json"
elif filter_option == "Peptide_Relaxed":
    filter_settings_path = "/content/bindcraft/settings_filters/peptide_relaxed_filters.json"
elif filter_option == "None":
    filter_settings_path = "/content/bindcraft/settings_filters/no_filters.json"
else:
    raise ValueError(f"Unsupported filter type")

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Filter settings updated at: {currenttime}")

# %% [markdown]
# # Everything is set, BindCraft is ready to run!

# %%
# @title Import functions and settings
from bindcraft.functions import *

args = {"settings":target_settings_path,
        "filters":filter_settings_path,
        "advanced":advanced_settings_path}

# Check if JAX-capable GPU is available, otherwise exit
check_jax_gpu()

# perform checks of input setting files
settings_path, filters_path, advanced_path = (args["settings"], args["filters"], args["advanced"])

### load settings from JSON
target_settings, advanced_settings, filters = load_json_settings(settings_path, filters_path, advanced_path)

settings_file = os.path.basename(settings_path).split('.')[0]
filters_file = os.path.basename(filters_path).split('.')[0]
advanced_file = os.path.basename(advanced_path).split('.')[0]

### load AF2 model settings
design_models, prediction_models, multimer_validation = load_af2_models(advanced_settings["use_multimer_design"])

### perform checks on advanced_settings
bindcraft_folder = "colab"
advanced_settings = perform_advanced_settings_check(advanced_settings, bindcraft_folder)

### generate directories, design path names can be found within the function
design_paths = generate_directories(target_settings["design_path"])

### generate dataframes
trajectory_labels, design_labels, final_labels = generate_dataframe_labels()

trajectory_csv = os.path.join(target_settings["design_path"], 'trajectory_stats.csv')
mpnn_csv = os.path.join(target_settings["design_path"], 'mpnn_design_stats.csv')
final_csv = os.path.join(target_settings["design_path"], 'final_design_stats.csv')
failure_csv = os.path.join(target_settings["design_path"], 'failure_csv.csv')

create_dataframe(trajectory_csv, trajectory_labels)
create_dataframe(mpnn_csv, design_labels)
create_dataframe(final_csv, final_labels)
generate_filter_pass_csv(failure_csv, args["filters"])

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Loaded design functions and settings at: {currenttime}")

# %%
#@title Initialise PyRosetta

####################################
####################################
####################################
### initialise PyRosetta
pr.init(f'-ignore_unrecognized_res -ignore_zero_occupancy -mute all -holes:dalphaball {advanced_settings["dalphaball_path"]} -corrections::beta_nov16 true -relax:default_repeats 1')

# %%
#@title Run BindCraft!
####################################
###################### BindCraft Run
####################################
# Colab-specific: live displays
num_sampled_trajectories = len(pd.read_csv(trajectory_csv))
num_accepted_designs = len(pd.read_csv(final_csv))
sampled_trajectories_label = HTML(value=f"<h3 style='color: #1f77b4;'>Sampled Trajectories: <span style='color: #1f77b4;'>{num_sampled_trajectories}</span></h3>")
accepted_designs_label = HTML(value=f"<h3 style='color: #2ca02c;'>Accepted Designs: <span style='color: #2ca02c;'>{num_accepted_designs}</span></h3>")
display(VBox([sampled_trajectories_label, accepted_designs_label]))

# initialise counters
script_start_time = time.time()
trajectory_n = 1
accepted_designs = 0

### start design loop
while True:
    ### check if we have the target number of binders
    final_designs_reached = check_accepted_designs(design_paths, mpnn_csv, final_labels, final_csv, advanced_settings, target_settings, design_labels)

    if final_designs_reached:
        # stop design loop execution
        break

    ### check if we reached maximum allowed trajectories
    max_trajectories_reached = check_n_trajectories(design_paths, advanced_settings)

    if max_trajectories_reached:
        break

    ### Initialise design
    # measure time to generate design
    trajectory_start_time = time.time()

    # generate random seed to vary designs
    seed = int(np.random.randint(0, high=999999, size=1, dtype=int)[0])

    # sample binder design length randomly from defined distribution
    samples = np.arange(min(target_settings["lengths"]), max(target_settings["lengths"]) + 1)
    length = np.random.choice(samples)

    # load desired helicity value to sample different secondary structure contents
    helicity_value = load_helicity(advanced_settings)

    # generate design name and check if same trajectory was already run
    design_name = target_settings["binder_name"] + "_l" + str(length) + "_s"+ str(seed)
    trajectory_dirs = ["Trajectory", "Trajectory/Relaxed", "Trajectory/LowConfidence", "Trajectory/Clashing"]
    trajectory_exists = any(os.path.exists(os.path.join(design_paths[trajectory_dir], design_name + ".pdb")) for trajectory_dir in trajectory_dirs)

    if not trajectory_exists:
        print("Starting trajectory: "+design_name)

        ### Begin binder hallucination
        trajectory = binder_hallucination(design_name, target_settings["starting_pdb"], target_settings["chains"],
                                            target_settings["target_hotspot_residues"], length, seed, helicity_value,
                                            design_models, advanced_settings, design_paths, failure_csv)
        trajectory_metrics = copy_dict(trajectory._tmp["best"]["aux"]["log"]) # contains plddt, ptm, i_ptm, pae, i_pae
        trajectory_pdb = os.path.join(design_paths["Trajectory"], design_name + ".pdb")

        # round the metrics to two decimal places
        trajectory_metrics = {k: round(v, 2) if isinstance(v, float) else v for k, v in trajectory_metrics.items()}

        # time trajectory
        trajectory_time = time.time() - trajectory_start_time
        trajectory_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(trajectory_time // 3600), int((trajectory_time % 3600) // 60), int(trajectory_time % 60))}"
        print("Starting trajectory took: "+trajectory_time_text)
        print("")

        # Proceed if there is no trajectory termination signal
        if trajectory.aux["log"]["terminate"] == "":
            # Relax binder to calculate statistics
            trajectory_relaxed = os.path.join(design_paths["Trajectory/Relaxed"], design_name + ".pdb")
            pr_relax(trajectory_pdb, trajectory_relaxed)

            # define binder chain, placeholder in case multi-chain parsing in ColabDesign gets changed
            binder_chain = "B"

            # Calculate clashes before and after relaxation
            num_clashes_trajectory = calculate_clash_score(trajectory_pdb)
            num_clashes_relaxed = calculate_clash_score(trajectory_relaxed)

            # secondary structure content of starting trajectory binder and interface
            trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_i_plddt, trajectory_ss_plddt = calc_ss_percentage(trajectory_pdb, advanced_settings, binder_chain)

            # analyze interface scores for relaxed af2 trajectory
            trajectory_interface_scores, trajectory_interface_AA, trajectory_interface_residues = score_interface(trajectory_relaxed, binder_chain)

            # starting binder sequence
            trajectory_sequence = trajectory.get_seq(get_best=True)[0]

            # analyze sequence
            traj_seq_notes = validate_design_sequence(trajectory_sequence, num_clashes_relaxed, advanced_settings)

            # target structure RMSD compared to input PDB
            trajectory_target_rmsd = unaligned_rmsd(target_settings["starting_pdb"], trajectory_pdb, target_settings["chains"], 'A')

            # save trajectory statistics into CSV
            trajectory_data = [design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], trajectory_sequence, trajectory_interface_residues,
                                trajectory_metrics['plddt'], trajectory_metrics['ptm'], trajectory_metrics['i_ptm'], trajectory_metrics['pae'], trajectory_metrics['i_pae'],
                                trajectory_i_plddt, trajectory_ss_plddt, num_clashes_trajectory, num_clashes_relaxed, trajectory_interface_scores['binder_score'],
                                trajectory_interface_scores['surface_hydrophobicity'], trajectory_interface_scores['interface_sc'], trajectory_interface_scores['interface_packstat'],
                                trajectory_interface_scores['interface_dG'], trajectory_interface_scores['interface_dSASA'], trajectory_interface_scores['interface_dG_SASA_ratio'],
                                trajectory_interface_scores['interface_fraction'], trajectory_interface_scores['interface_hydrophobicity'], trajectory_interface_scores['interface_nres'], trajectory_interface_scores['interface_interface_hbonds'],
                                trajectory_interface_scores['interface_hbond_percentage'], trajectory_interface_scores['interface_delta_unsat_hbonds'], trajectory_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_interface_AA, trajectory_target_rmsd,
                                trajectory_time_text, traj_seq_notes, settings_file, filters_file, advanced_file]
            insert_data(trajectory_csv, trajectory_data)

            if advanced_settings["enable_mpnn"]:
                # initialise MPNN counters
                mpnn_n = 1
                accepted_mpnn = 0
                mpnn_dict = {}
                design_start_time = time.time()

                ### MPNN redesign of starting binder
                mpnn_trajectories = mpnn_gen_sequence(trajectory_pdb, binder_chain, trajectory_interface_residues, advanced_settings)
                existing_mpnn_sequences = set(pd.read_csv(mpnn_csv, usecols=['Sequence'])['Sequence'].values)

                # create set of MPNN sequences with allowed amino acid composition
                restricted_AAs = set(aa.strip().upper() for aa in advanced_settings["omit_AAs"].split(',')) if advanced_settings["force_reject_AA"] else set()

                mpnn_sequences = sorted({
                    mpnn_trajectories['seq'][n][-length:]: {
                        'seq': mpnn_trajectories['seq'][n][-length:],
                        'score': mpnn_trajectories['score'][n],
                        'seqid': mpnn_trajectories['seqid'][n]
                    } for n in range(advanced_settings["num_seqs"])
                    if (not restricted_AAs or not any(aa in mpnn_trajectories['seq'][n][-length:].upper() for aa in restricted_AAs))
                    and mpnn_trajectories['seq'][n][-length:] not in existing_mpnn_sequences
                }.values(), key=lambda x: x['score'])

                del existing_mpnn_sequences

                # check whether any sequences are left after amino acid rejection and duplication check, and if yes proceed with prediction
                if mpnn_sequences:
                    # add optimisation for increasing recycles if trajectory is beta sheeted
                    if advanced_settings["optimise_beta"] and float(trajectory_beta) > 15:
                        advanced_settings["num_recycles_validation"] = advanced_settings["optimise_beta_recycles_valid"]

                    ### Compile prediction models once for faster prediction of MPNN sequences
                    clear_mem()
                    # compile complex prediction model
                    complex_prediction_model = mk_afdesign_model(protocol="binder", num_recycles=advanced_settings["num_recycles_validation"], data_dir=advanced_settings["af_params_dir"],
                                                                use_multimer=multimer_validation)
                    complex_prediction_model.prep_inputs(pdb_filename=target_settings["starting_pdb"], chain=target_settings["chains"], binder_len=length, rm_target_seq=advanced_settings["rm_template_seq_predict"],
                                                        rm_target_sc=advanced_settings["rm_template_sc_predict"])

                    # compile binder monomer prediction model
                    binder_prediction_model = mk_afdesign_model(protocol="hallucination", use_templates=False, initial_guess=False,
                                                                use_initial_atom_pos=False, num_recycles=advanced_settings["num_recycles_validation"],
                                                                data_dir=advanced_settings["af_params_dir"], use_multimer=multimer_validation)
                    binder_prediction_model.prep_inputs(length=length)

                    # iterate over designed sequences
                    for mpnn_sequence in mpnn_sequences:
                        mpnn_time = time.time()

                        # generate mpnn design name numbering
                        mpnn_design_name = design_name + "_mpnn" + str(mpnn_n)
                        mpnn_score = round(mpnn_sequence['score'],2)
                        mpnn_seqid = round(mpnn_sequence['seqid'],2)

                        # add design to dictionary
                        mpnn_dict[mpnn_design_name] = {'seq': mpnn_sequence['seq'], 'score': mpnn_score, 'seqid': mpnn_seqid}

                        # save fasta sequence
                        if advanced_settings["save_mpnn_fasta"] is True:
                            save_fasta(mpnn_design_name, mpnn_sequence['seq'], design_paths)

                        ### Predict mpnn redesigned binder complex using masked templates
                        mpnn_complex_statistics, pass_af2_filters = predict_binder_complex(complex_prediction_model,
                                                                                        mpnn_sequence['seq'], mpnn_design_name,
                                                                                        target_settings["starting_pdb"], target_settings["chains"],
                                                                                        length, trajectory_pdb, prediction_models, advanced_settings,
                                                                                        filters, design_paths, failure_csv)

                        # if AF2 filters are not passed then skip the scoring
                        if not pass_af2_filters:
                            print(f"Base AF2 filters not passed for {mpnn_design_name}, skipping interface scoring")
                            mpnn_n += 1
                            continue

                        # calculate statistics for each model individually
                        for model_num in prediction_models:
                            mpnn_design_pdb = os.path.join(design_paths["MPNN"], f"{mpnn_design_name}_model{model_num+1}.pdb")
                            mpnn_design_relaxed = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_design_pdb):
                                # Calculate clashes before and after relaxation
                                num_clashes_mpnn = calculate_clash_score(mpnn_design_pdb)
                                num_clashes_mpnn_relaxed = calculate_clash_score(mpnn_design_relaxed)

                                # analyze interface scores for relaxed af2 trajectory
                                mpnn_interface_scores, mpnn_interface_AA, mpnn_interface_residues = score_interface(mpnn_design_relaxed, binder_chain)

                                # secondary structure content of starting trajectory binder
                                mpnn_alpha, mpnn_beta, mpnn_loops, mpnn_alpha_interface, mpnn_beta_interface, mpnn_loops_interface, mpnn_i_plddt, mpnn_ss_plddt = calc_ss_percentage(mpnn_design_pdb, advanced_settings, binder_chain)

                                # unaligned RMSD calculate to determine if binder is in the designed binding site
                                rmsd_site = unaligned_rmsd(trajectory_pdb, mpnn_design_pdb, binder_chain, binder_chain)

                                # calculate RMSD of target compared to input PDB
                                target_rmsd = target_pdb_rmsd(mpnn_design_pdb, target_settings["starting_pdb"], target_settings["chains"])

                                # add the additional statistics to the mpnn_complex_statistics dictionary
                                mpnn_complex_statistics[model_num+1].update({
                                    'i_pLDDT': mpnn_i_plddt,
                                    'ss_pLDDT': mpnn_ss_plddt,
                                    'Unrelaxed_Clashes': num_clashes_mpnn,
                                    'Relaxed_Clashes': num_clashes_mpnn_relaxed,
                                    'Binder_Energy_Score': mpnn_interface_scores['binder_score'],
                                    'Surface_Hydrophobicity': mpnn_interface_scores['surface_hydrophobicity'],
                                    'ShapeComplementarity': mpnn_interface_scores['interface_sc'],
                                    'PackStat': mpnn_interface_scores['interface_packstat'],
                                    'dG': mpnn_interface_scores['interface_dG'],
                                    'dSASA': mpnn_interface_scores['interface_dSASA'],
                                    'dG/dSASA': mpnn_interface_scores['interface_dG_SASA_ratio'],
                                    'Interface_SASA_%': mpnn_interface_scores['interface_fraction'],
                                    'Interface_Hydrophobicity': mpnn_interface_scores['interface_hydrophobicity'],
                                    'n_InterfaceResidues': mpnn_interface_scores['interface_nres'],
                                    'n_InterfaceHbonds': mpnn_interface_scores['interface_interface_hbonds'],
                                    'InterfaceHbondsPercentage': mpnn_interface_scores['interface_hbond_percentage'],
                                    'n_InterfaceUnsatHbonds': mpnn_interface_scores['interface_delta_unsat_hbonds'],
                                    'InterfaceUnsatHbondsPercentage': mpnn_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                    'InterfaceAAs': mpnn_interface_AA,
                                    'Interface_Helix%': mpnn_alpha_interface,
                                    'Interface_BetaSheet%': mpnn_beta_interface,
                                    'Interface_Loop%': mpnn_loops_interface,
                                    'Binder_Helix%': mpnn_alpha,
                                    'Binder_BetaSheet%': mpnn_beta,
                                    'Binder_Loop%': mpnn_loops,
                                    'Hotspot_RMSD': rmsd_site,
                                    'Target_RMSD': target_rmsd
                                })

                                # save space by removing unrelaxed predicted mpnn complex pdb?
                                if advanced_settings["remove_unrelaxed_complex"]:
                                    os.remove(mpnn_design_pdb)

                        # calculate complex averages
                        mpnn_complex_averages = calculate_averages(mpnn_complex_statistics, handle_aa=True)

                        ### Predict binder alone in single sequence mode
                        binder_statistics = predict_binder_alone(binder_prediction_model, mpnn_sequence['seq'], mpnn_design_name, length,
                                                                trajectory_pdb, binder_chain, prediction_models, advanced_settings, design_paths)

                        # extract RMSDs of binder to the original trajectory
                        for model_num in prediction_models:
                            mpnn_binder_pdb = os.path.join(design_paths["MPNN/Binder"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_binder_pdb):
                                rmsd_binder = unaligned_rmsd(trajectory_pdb, mpnn_binder_pdb, binder_chain, "A")

                            # append to statistics
                            binder_statistics[model_num+1].update({
                                    'Binder_RMSD': rmsd_binder
                                })

                            # save space by removing binder monomer models?
                            if advanced_settings["remove_binder_monomer"]:
                                os.remove(mpnn_binder_pdb)

                        # calculate binder averages
                        binder_averages = calculate_averages(binder_statistics)

                        # analyze sequence to make sure there are no cysteins and it contains residues that absorb UV for detection
                        seq_notes = validate_design_sequence(mpnn_sequence['seq'], mpnn_complex_averages.get('Relaxed_Clashes', None), advanced_settings)

                        # measure time to generate design
                        mpnn_end_time = time.time() - mpnn_time
                        elapsed_mpnn_text = f"{'%d hours, %d minutes, %d seconds' % (int(mpnn_end_time // 3600), int((mpnn_end_time % 3600) // 60), int(mpnn_end_time % 60))}"


                        # Insert statistics about MPNN design into CSV, will return None if corresponding model does note exist
                        model_numbers = range(1, 6)
                        statistics_labels = ['pLDDT', 'pTM', 'i_pTM', 'pAE', 'i_pAE', 'i_pLDDT', 'ss_pLDDT', 'Unrelaxed_Clashes', 'Relaxed_Clashes', 'Binder_Energy_Score', 'Surface_Hydrophobicity',
                                            'ShapeComplementarity', 'PackStat', 'dG', 'dSASA', 'dG/dSASA', 'Interface_SASA_%', 'Interface_Hydrophobicity', 'n_InterfaceResidues', 'n_InterfaceHbonds', 'InterfaceHbondsPercentage',
                                            'n_InterfaceUnsatHbonds', 'InterfaceUnsatHbondsPercentage', 'Interface_Helix%', 'Interface_BetaSheet%', 'Interface_Loop%', 'Binder_Helix%',
                                            'Binder_BetaSheet%', 'Binder_Loop%', 'InterfaceAAs', 'Hotspot_RMSD', 'Target_RMSD']

                        # Initialize mpnn_data with the non-statistical data
                        mpnn_data = [mpnn_design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], mpnn_sequence['seq'], mpnn_interface_residues, mpnn_score, mpnn_seqid]

                        # Add the statistical data for mpnn_complex
                        for label in statistics_labels:
                            mpnn_data.append(mpnn_complex_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(mpnn_complex_statistics.get(model, {}).get(label, None))

                        # Add the statistical data for binder
                        for label in ['pLDDT', 'pTM', 'pAE', 'Binder_RMSD']:  # These are the labels for binder alone
                            mpnn_data.append(binder_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(binder_statistics.get(model, {}).get(label, None))

                        # Add the remaining non-statistical data
                        mpnn_data.extend([elapsed_mpnn_text, seq_notes, settings_file, filters_file, advanced_file])

                        # insert data into csv
                        insert_data(mpnn_csv, mpnn_data)

                        # find best model number by pLDDT
                        plddt_values = {i: mpnn_data[i] for i in range(11, 15) if mpnn_data[i] is not None}

                        # Find the key with the highest value
                        highest_plddt_key = int(max(plddt_values, key=plddt_values.get))

                        # Output the number part of the key
                        best_model_number = highest_plddt_key - 10
                        best_model_pdb = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{best_model_number}.pdb")

                        # run design data against filter thresholds
                        filter_conditions = check_filters(mpnn_data, design_labels, filters)
                        if filter_conditions == True:
                            print(mpnn_design_name+" passed all filters")
                            accepted_mpnn += 1
                            accepted_designs += 1

                            # copy designs to accepted folder
                            shutil.copy(best_model_pdb, design_paths["Accepted"])

                            # insert data into final csv
                            final_data = [''] + mpnn_data
                            insert_data(final_csv, final_data)

                            # copy animation from accepted trajectory
                            if advanced_settings["save_design_animations"]:
                                accepted_animation = os.path.join(design_paths["Accepted/Animation"], f"{design_name}.html")
                                if not os.path.exists(accepted_animation):
                                    shutil.copy(os.path.join(design_paths["Trajectory/Animation"], f"{design_name}.html"), accepted_animation)

                            # copy plots of accepted trajectory
                            plot_files = os.listdir(design_paths["Trajectory/Plots"])
                            plots_to_copy = [f for f in plot_files if f.startswith(design_name) and f.endswith('.png')]
                            for accepted_plot in plots_to_copy:
                                source_plot = os.path.join(design_paths["Trajectory/Plots"], accepted_plot)
                                target_plot = os.path.join(design_paths["Accepted/Plots"], accepted_plot)
                                if not os.path.exists(target_plot):
                                    shutil.copy(source_plot, target_plot)

                        else:
                            print(f"Unmet filter conditions for {mpnn_design_name}")
                            failure_df = pd.read_csv(failure_csv)
                            special_prefixes = ('Average_', '1_', '2_', '3_', '4_', '5_')
                            incremented_columns = set()

                            for column in filter_conditions:
                                base_column = column
                                for prefix in special_prefixes:
                                    if column.startswith(prefix):
                                        base_column = column.split('_', 1)[1]

                                if base_column not in incremented_columns:
                                    failure_df[base_column] = failure_df[base_column] + 1
                                    incremented_columns.add(base_column)

                            failure_df.to_csv(failure_csv, index=False)
                            shutil.copy(best_model_pdb, design_paths["Rejected"])

                        # increase MPNN design number
                        mpnn_n += 1

                        # if enough mpnn sequences of the same trajectory pass filters then stop
                        if accepted_mpnn >= advanced_settings["max_mpnn_sequences"]:
                            break

                    if accepted_mpnn >= 1:
                        print("Found "+str(accepted_mpnn)+" MPNN designs passing filters")
                    else:
                        print("No accepted MPNN designs found for this trajectory.")

                else:
                    print('Duplicate MPNN designs sampled with different trajectory, skipping current trajectory optimisation')

                # save space by removing unrelaxed design trajectory PDB
                if advanced_settings["remove_unrelaxed_trajectory"]:
                    os.remove(trajectory_pdb)

                # measure time it took to generate designs for one trajectory
                design_time = time.time() - design_start_time
                design_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(design_time // 3600), int((design_time % 3600) // 60), int(design_time % 60))}"
                print("Design and validation of trajectory "+design_name+" took: "+design_time_text)

            # analyse the rejection rate of trajectories to see if we need to readjust the design weights
            if trajectory_n >= advanced_settings["start_monitoring"] and advanced_settings["enable_rejection_check"]:
                acceptance = accepted_designs / trajectory_n
                if not acceptance >= advanced_settings["acceptance_rate"]:
                    print("The ratio of successful designs is lower than defined acceptance rate! Consider changing your design settings!")
                    print("Script execution stopping...")
                    break

        # increase trajectory number
        trajectory_n += 1

        # Colab-specific: update counters
        num_sampled_trajectories = len(pd.read_csv(trajectory_csv))
        num_accepted_designs = len(pd.read_csv(final_csv))
        sampled_trajectories_label.value = f"Sampled trajectories: {num_sampled_trajectories}"
        accepted_designs_label.value = f"Accepted designs: {num_accepted_designs}"

### Script finished
elapsed_time = time.time() - script_start_time
elapsed_text = f"{'%d hours, %d minutes, %d seconds' % (int(elapsed_time // 3600), int((elapsed_time % 3600) // 60), int(elapsed_time % 60))}"
print("Finished all designs. Script execution for "+str(trajectory_n)+" trajectories took: "+elapsed_text)
# Out:
# VBox(children=(HTML(value="<h3 style='color: #1f77b4;'>Sampled Trajectories: <span style='color: #1f77b4;'>0</…
# Starting trajectory: CTNI_l90_s547910
# Stage 1: Test Logits
# 1 models [2] recycles 1 hard 0 soft 0.02 temp 1 loss 12.83 helix 1.16 pae 0.87 i_pae 0.93 con 4.68 i_con 4.98 plddt 0.35 ptm 0.39 i_ptm 0.10 rg 9.92
# 2 models [4] recycles 1 hard 0 soft 0.04 temp 1 loss 11.38 helix 0.39 pae 0.75 i_pae 0.86 con 4.24 i_con 4.62 plddt 0.50 ptm 0.40 i_ptm 0.15 rg 7.20
# 3 models [3] recycles 1 hard 0 soft 0.05 temp 1 loss 10.79 helix 0.51 pae 0.75 i_pae 0.85 con 4.16 i_con 4.54 plddt 0.45 ptm 0.42 i_ptm 0.16 rg 5.87
# 4 models [2] recycles 1 hard 0 soft 0.07 temp 1 loss 10.75 helix 0.40 pae 0.70 i_pae 0.83 con 3.82 i_con 4.51 plddt 0.53 ptm 0.39 i_ptm 0.19 rg 6.99
# 5 models [3] recycles 1 hard 0 soft 0.09 temp 1 loss 10.28 helix 0.50 pae 0.67 i_pae 0.79 con 3.74 i_con 4.10 plddt 0.51 ptm 0.42 i_ptm 0.28 rg 7.18
# 6 models [1] recycles 1 hard 0 soft 0.11 temp 1 loss 10.02 helix 0.55 pae 0.62 i_pae 0.72 con 3.63 i_con 3.98 plddt 0.56 ptm 0.44 i_ptm 0.34 rg 7.26
# 7 models [3] recycles 1 hard 0 soft 0.13 temp 1 loss 9.08 helix 0.48 pae 0.53 i_pae 0.64 con 3.09 i_con 3.51 plddt 0.66 ptm 0.50 i_ptm 0.49 rg 7.61
# 8 models [2] recycles 1 hard 0 soft 0.14 temp 1 loss 9.81 helix 0.45 pae 0.59 i_pae 0.69 con 3.48 i_con 3.81 plddt 0.58 ptm 0.44 i_ptm 0.36 rg 7.60
# 9 models [4] recycles 1 hard 0 soft 0.16 temp 1 loss 8.12 helix 0.35 pae 0.45 i_pae 0.56 con 2.55 i_con 3.05 plddt 0.75 ptm 0.50 i_ptm 0.60 rg 7.80
# 10 models [3] recycles 1 hard 0 soft 0.18 temp 1 loss 8.54 helix 0.45 pae 0.49 i_pae 0.59 con 2.75 i_con 3.26 plddt 0.72 ptm 0.51 i_ptm 0.55 rg 7.86
# 11 models [0] recycles 1 hard 0 soft 0.20 temp 1 loss 7.51 helix 0.31 pae 0.40 i_pae 0.50 con 2.28 i_con 2.72 plddt 0.79 ptm 0.54 i_ptm 0.71 rg 7.85
# 12 models [1] recycles 1 hard 0 soft 0.22 temp 1 loss 8.19 helix 0.39 pae 0.44 i_pae 0.53 con 2.78 i_con 2.93 plddt 0.73 ptm 0.54 i_ptm 0.68 rg 7.76
# 13 models [1] recycles 1 hard 0 soft 0.23 temp 1 loss 10.09 helix 0.48 pae 0.58 i_pae 0.64 con 4.10 i_con 3.47 plddt 0.59 ptm 0.51 i_ptm 0.49 rg 7.64
# 14 models [3] recycles 1 hard 0 soft 0.25 temp 1 loss 8.89 helix 0.75 pae 0.77 i_pae 0.89 con 3.71 i_con 4.68 plddt 0.41 ptm 0.39 i_ptm 0.12 rg 0.76
# 15 models [1] recycles 1 hard 0 soft 0.27 temp 1 loss 9.00 helix 0.72 pae 0.74 i_pae 0.85 con 3.80 i_con 4.55 plddt 0.44 ptm 0.40 i_ptm 0.17 rg 1.32
# 16 models [4] recycles 1 hard 0 soft 0.29 temp 1 loss 8.30 helix 0.73 pae 0.73 i_pae 0.86 con 3.41 i_con 4.51 plddt 0.48 ptm 0.38 i_ptm 0.15 rg 0.46
# 17 models [1] recycles 1 hard 0 soft 0.31 temp 1 loss 8.83 helix 0.70 pae 0.75 i_pae 0.92 con 3.48 i_con 5.00 plddt 0.51 ptm 0.36 i_ptm 0.10 rg 0.22
# 18 models [3] recycles 1 hard 0 soft 0.32 temp 1 loss 8.24 helix 0.73 pae 0.70 i_pae 0.83 con 3.53 i_con 4.34 plddt 0.46 ptm 0.42 i_ptm 0.19 rg 0.40
# 19 models [4] recycles 1 hard 0 soft 0.34 temp 1 loss 6.96 helix 0.68 pae 0.57 i_pae 0.66 con 3.14 i_con 3.44 plddt 0.59 ptm 0.50 i_ptm 0.50 rg 0.77
# 20 models [2] recycles 1 hard 0 soft 0.36 temp 1 loss 6.95 helix 0.67 pae 0.54 i_pae 0.62 con 3.29 i_con 3.24 plddt 0.61 ptm 0.51 i_ptm 0.61 rg 0.95
# 21 models [3] recycles 1 hard 0 soft 0.38 temp 1 loss 6.13 helix 0.75 pae 0.46 i_pae 0.56 con 2.76 i_con 3.00 plddt 0.72 ptm 0.56 i_ptm 0.69 rg 1.05
# 22 models [2] recycles 1 hard 0 soft 0.40 temp 1 loss 5.92 helix 0.71 pae 0.45 i_pae 0.55 con 2.66 i_con 2.80 plddt 0.75 ptm 0.55 i_ptm 0.74 rg 1.33
# 23 models [2] recycles 1 hard 0 soft 0.41 temp 1 loss 4.96 helix 0.78 pae 0.41 i_pae 0.52 con 2.19 i_con 2.41 plddt 0.83 ptm 0.57 i_ptm 0.83 rg 1.17
# 24 models [4] recycles 1 hard 0 soft 0.43 temp 1 loss 4.89 helix 0.84 pae 0.40 i_pae 0.50 con 2.09 i_con 2.48 plddt 0.83 ptm 0.59 i_ptm 0.79 rg 1.12
# 25 models [1] recycles 1 hard 0 soft 0.45 temp 1 loss 4.95 helix 0.82 pae 0.39 i_pae 0.50 con 2.18 i_con 2.49 plddt 0.81 ptm 0.57 i_ptm 0.79 rg 0.95
# 26 models [1] recycles 1 hard 0 soft 0.47 temp 1 loss 4.38 helix 0.87 pae 0.35 i_pae 0.44 con 2.00 i_con 2.14 plddt 0.86 ptm 0.63 i_ptm 0.87 rg 1.00
# 27 models [3] recycles 1 hard 0 soft 0.49 temp 1 loss 4.05 helix 0.88 pae 0.35 i_pae 0.45 con 1.85 i_con 1.92 plddt 0.88 ptm 0.62 i_ptm 0.89 rg 1.13
# 28 models [0] recycles 1 hard 0 soft 0.50 temp 1 loss 8.02 helix 0.72 pae 0.72 i_pae 0.92 con 2.72 i_con 5.10 plddt 0.60 ptm 0.36 i_ptm 0.11 rg -0.14
# 29 models [3] recycles 1 hard 0 soft 0.52 temp 1 loss 4.07 helix 0.92 pae 0.35 i_pae 0.44 con 1.86 i_con 1.98 plddt 0.88 ptm 0.63 i_ptm 0.89 rg 1.00
# 30 models [2] recycles 1 hard 0 soft 0.54 temp 1 loss 3.84 helix 0.99 pae 0.36 i_pae 0.46 con 1.77 i_con 1.84 plddt 0.89 ptm 0.62 i_ptm 0.90 rg 1.08
# 31 models [1] recycles 1 hard 0 soft 0.56 temp 1 loss 4.09 helix 0.88 pae 0.32 i_pae 0.41 con 1.89 i_con 1.97 plddt 0.88 ptm 0.66 i_ptm 0.89 rg 1.03
# 32 models [4] recycles 1 hard 0 soft 0.58 temp 1 loss 4.02 helix 1.01 pae 0.31 i_pae 0.40 con 1.83 i_con 1.95 plddt 0.90 ptm 0.66 i_ptm 0.90 rg 1.20
# 33 models [0] recycles 1 hard 0 soft 0.59 temp 1 loss 6.11 helix 0.80 pae 0.45 i_pae 0.53 con 2.85 i_con 3.01 plddt 0.64 ptm 0.58 i_ptm 0.67 rg 0.68
# 34 models [0] recycles 1 hard 0 soft 0.61 temp 1 loss 5.89 helix 0.82 pae 0.44 i_pae 0.52 con 2.71 i_con 2.90 plddt 0.66 ptm 0.58 i_ptm 0.70 rg 0.86
# 35 models [2] recycles 1 hard 0 soft 0.63 temp 1 loss 8.97 helix 0.52 pae 0.62 i_pae 0.71 con 3.70 i_con 3.73 plddt 0.53 ptm 0.45 i_ptm 0.41 rg 4.30
# 36 models [2] recycles 1 hard 0 soft 0.65 temp 1 loss 6.14 helix 0.78 pae 0.49 i_pae 0.58 con 2.77 i_con 3.04 plddt 0.66 ptm 0.53 i_ptm 0.64 rg 0.86
# 37 models [3] recycles 1 hard 0 soft 0.67 temp 1 loss 6.22 helix 0.83 pae 0.46 i_pae 0.55 con 2.99 i_con 2.97 plddt 0.68 ptm 0.55 i_ptm 0.69 rg 0.76
# 38 models [1] recycles 1 hard 0 soft 0.68 temp 1 loss 5.44 helix 0.87 pae 0.39 i_pae 0.47 con 2.70 i_con 2.60 plddt 0.73 ptm 0.61 i_ptm 0.80 rg 0.56
# 39 models [0] recycles 1 hard 0 soft 0.70 temp 1 loss 4.89 helix 0.89 pae 0.35 i_pae 0.43 con 2.40 i_con 2.39 plddt 0.78 ptm 0.64 i_ptm 0.83 rg 0.52
# 40 models [3] recycles 1 hard 0 soft 0.72 temp 1 loss 5.58 helix 0.87 pae 0.43 i_pae 0.51 con 2.70 i_con 2.72 plddt 0.71 ptm 0.59 i_ptm 0.76 rg 0.55
# 41 models [4] recycles 1 hard 0 soft 0.74 temp 1 loss 4.70 helix 0.93 pae 0.36 i_pae 0.44 con 2.28 i_con 2.30 plddt 0.81 ptm 0.63 i_ptm 0.85 rg 0.59
# 42 models [1] recycles 1 hard 0 soft 0.76 temp 1 loss 4.64 helix 0.94 pae 0.34 i_pae 0.42 con 2.28 i_con 2.28 plddt 0.82 ptm 0.64 i_ptm 0.86 rg 0.53
# 43 models [3] recycles 1 hard 0 soft 0.77 temp 1 loss 4.38 helix 0.94 pae 0.33 i_pae 0.41 con 2.17 i_con 2.13 plddt 0.86 ptm 0.65 i_ptm 0.88 rg 0.57
# 44 models [0] recycles 1 hard 0 soft 0.79 temp 1 loss 8.49 helix 0.66 pae 0.72 i_pae 0.90 con 3.20 i_con 5.05 plddt 0.56 ptm 0.39 i_ptm 0.14 rg -0.06
# 45 models [3] recycles 1 hard 0 soft 0.81 temp 1 loss 6.00 helix 0.69 pae 0.48 i_pae 0.55 con 2.75 i_con 2.78 plddt 0.70 ptm 0.57 i_ptm 0.71 rg 1.29
# 46 models [1] recycles 1 hard 0 soft 0.83 temp 1 loss 8.16 helix 0.66 pae 0.51 i_pae 0.58 con 3.45 i_con 3.22 plddt 0.60 ptm 0.54 i_ptm 0.62 rg 4.52
# 47 models [2] recycles 1 hard 0 soft 0.85 temp 1 loss 7.07 helix 0.66 pae 0.55 i_pae 0.63 con 3.46 i_con 3.29 plddt 0.59 ptm 0.52 i_ptm 0.59 rg 0.57
# 48 models [1] recycles 1 hard 0 soft 0.86 temp 1 loss 9.89 helix 0.68 pae 0.63 i_pae 0.72 con 3.52 i_con 3.94 plddt 0.53 ptm 0.45 i_ptm 0.39 rg 7.40
# 49 models [4] recycles 1 hard 0 soft 0.88 temp 1 loss 6.81 helix 0.69 pae 0.53 i_pae 0.60 con 3.27 i_con 3.25 plddt 0.59 ptm 0.53 i_ptm 0.58 rg 0.55
# 50 models [3] recycles 1 hard 0 soft 0.90 temp 1 loss 9.20 helix 0.51 pae 0.59 i_pae 0.73 con 3.03 i_con 3.70 plddt 0.66 ptm 0.46 i_ptm 0.43 rg 7.50
# Initial trajectory pLDDT good, continuing: 0.89
# Stage 1: Additional Logits Optimisation
# 51 models [2] recycles 1 hard 0 soft 0.04 temp 1 loss 6.13 helix 0.76 pae 0.47 i_pae 0.56 con 2.81 i_con 3.00 plddt 0.68 ptm 0.57 i_ptm 0.68 rg 0.89
# 52 models [4] recycles 1 hard 0 soft 0.08 temp 1 loss 4.86 helix 0.95 pae 0.35 i_pae 0.43 con 2.32 i_con 2.30 plddt 0.82 ptm 0.64 i_ptm 0.85 rg 1.03
# 53 models [4] recycles 1 hard 0 soft 0.12 temp 1 loss 4.36 helix 1.08 pae 0.32 i_pae 0.41 con 2.12 i_con 2.09 plddt 0.86 ptm 0.66 i_ptm 0.88 rg 0.96
# 54 models [0] recycles 1 hard 0 soft 0.16 temp 1 loss 4.27 helix 1.12 pae 0.31 i_pae 0.38 con 2.17 i_con 2.05 plddt 0.85 ptm 0.67 i_ptm 0.88 rg 0.69
# 55 models [2] recycles 1 hard 0 soft 0.20 temp 1 loss 4.78 helix 1.08 pae 0.37 i_pae 0.46 con 2.39 i_con 2.22 plddt 0.81 ptm 0.62 i_ptm 0.86 rg 0.90
# 56 models [0] recycles 1 hard 0 soft 0.24 temp 1 loss 4.33 helix 1.08 pae 0.31 i_pae 0.39 con 2.17 i_con 2.07 plddt 0.84 ptm 0.67 i_ptm 0.88 rg 0.74
# 57 models [2] recycles 1 hard 0 soft 0.28 temp 1 loss 4.00 helix 1.25 pae 0.32 i_pae 0.40 con 1.98 i_con 1.98 plddt 0.88 ptm 0.66 i_ptm 0.90 rg 0.79
# 58 models [0] recycles 1 hard 0 soft 0.32 temp 1 loss 3.97 helix 1.16 pae 0.30 i_pae 0.38 con 1.93 i_con 1.99 plddt 0.88 ptm 0.68 i_ptm 0.89 rg 0.74
# 59 models [0] recycles 1 hard 0 soft 0.36 temp 1 loss 3.56 helix 1.26 pae 0.29 i_pae 0.37 con 1.75 i_con 1.81 plddt 0.90 ptm 0.69 i_ptm 0.91 rg 0.72
# 60 models [3] recycles 1 hard 0 soft 0.40 temp 1 loss 3.62 helix 1.19 pae 0.30 i_pae 0.38 con 1.80 i_con 1.77 plddt 0.91 ptm 0.68 i_ptm 0.91 rg 0.82
# 61 models [1] recycles 1 hard 0 soft 0.44 temp 1 loss 3.50 helix 1.34 pae 0.31 i_pae 0.40 con 1.75 i_con 1.78 plddt 0.90 ptm 0.67 i_ptm 0.91 rg 0.65
# 62 models [1] recycles 1 hard 0 soft 0.48 temp 1 loss 3.40 helix 1.46 pae 0.30 i_pae 0.39 con 1.74 i_con 1.74 plddt 0.91 ptm 0.68 i_ptm 0.92 rg 0.64
# 63 models [2] recycles 1 hard 0 soft 0.52 temp 1 loss 3.42 helix 1.35 pae 0.31 i_pae 0.39 con 1.71 i_con 1.72 plddt 0.93 ptm 0.67 i_ptm 0.92 rg 0.74
# 64 models [3] recycles 1 hard 0 soft 0.56 temp 1 loss 3.32 helix 1.33 pae 0.30 i_pae 0.39 con 1.65 i_con 1.69 plddt 0.93 ptm 0.67 i_ptm 0.92 rg 0.70
# 65 models [4] recycles 1 hard 0 soft 0.60 temp 1 loss 3.30 helix 1.37 pae 0.30 i_pae 0.39 con 1.60 i_con 1.72 plddt 0.93 ptm 0.67 i_ptm 0.91 rg 0.72
# 66 models [3] recycles 1 hard 0 soft 0.64 temp 1 loss 3.20 helix 1.46 pae 0.29 i_pae 0.38 con 1.59 i_con 1.67 plddt 0.94 ptm 0.67 i_ptm 0.92 rg 0.73
# 67 models [4] recycles 1 hard 0 soft 0.68 temp 1 loss 3.26 helix 1.38 pae 0.29 i_pae 0.39 con 1.59 i_con 1.70 plddt 0.94 ptm 0.67 i_ptm 0.92 rg 0.73
# 68 models [4] recycles 1 hard 0 soft 0.72 temp 1 loss 4.29 helix 1.27 pae 0.36 i_pae 0.45 con 1.99 i_con 2.22 plddt 0.84 ptm 0.63 i_ptm 0.84 rg 0.82
# 69 models [3] recycles 1 hard 0 soft 0.76 temp 1 loss 3.06 helix 1.63 pae 0.28 i_pae 0.37 con 1.53 i_con 1.63 plddt 0.95 ptm 0.69 i_ptm 0.93 rg 0.74
# 70 models [1] recycles 1 hard 0 soft 0.80 temp 1 loss 6.31 helix 0.93 pae 0.39 i_pae 0.46 con 2.64 i_con 2.46 plddt 0.77 ptm 0.62 i_ptm 0.81 rg 4.19
# 71 models [0] recycles 1 hard 0 soft 0.84 temp 1 loss 7.18 helix 1.08 pae 0.67 i_pae 0.88 con 2.25 i_con 4.88 plddt 0.70 ptm 0.37 i_ptm 0.15 rg -0.16
# 72 models [0] recycles 1 hard 0 soft 0.88 temp 1 loss 7.19 helix 1.02 pae 0.67 i_pae 0.89 con 2.19 i_con 4.85 plddt 0.73 ptm 0.36 i_ptm 0.13 rg 0.09
# 73 models [1] recycles 1 hard 0 soft 0.92 temp 1 loss 9.58 helix 0.68 pae 0.59 i_pae 0.65 con 3.60 i_con 3.57 plddt 0.55 ptm 0.50 i_ptm 0.49 rg 7.47
# 74 models [2] recycles 1 hard 0 soft 0.96 temp 1 loss 7.24 helix 0.72 pae 0.58 i_pae 0.64 con 3.45 i_con 3.39 plddt 0.56 ptm 0.51 i_ptm 0.55 rg 0.86
# 75 models [1] recycles 1 hard 0 soft 1 temp 1 loss 10.21 helix 0.75 pae 0.77 i_pae 0.86 con 3.97 i_con 4.56 plddt 0.39 ptm 0.40 i_ptm 0.17 rg 4.71
# Optimised logit trajectory pLDDT: 0.95
# Stage 2: Softmax Optimisation
# 76 models [2] recycles 1 hard 0 soft 1 temp 0.96 loss 7.18 helix 0.81 pae 0.59 i_pae 0.65 con 3.54 i_con 3.41 plddt 0.53 ptm 0.51 i_ptm 0.53 rg 0.33
# 77 models [4] recycles 1 hard 0 soft 1 temp 0.91 loss 4.80 helix 0.93 pae 0.37 i_pae 0.47 con 2.20 i_con 2.43 plddt 0.81 ptm 0.61 i_ptm 0.82 rg 0.75
# 78 models [0] recycles 1 hard 0 soft 1 temp 0.87 loss 4.65 helix 1.08 pae 0.34 i_pae 0.43 con 2.22 i_con 2.38 plddt 0.82 ptm 0.63 i_ptm 0.84 rg 0.59
# 79 models [3] recycles 1 hard 0 soft 1 temp 0.83 loss 3.94 helix 1.14 pae 0.30 i_pae 0.39 con 1.92 i_con 1.98 plddt 0.90 ptm 0.66 i_ptm 0.89 rg 0.72
# 80 models [3] recycles 1 hard 0 soft 1 temp 0.79 loss 3.31 helix 1.46 pae 0.28 i_pae 0.37 con 1.67 i_con 1.69 plddt 0.93 ptm 0.68 i_ptm 0.92 rg 0.76
# 81 models [4] recycles 1 hard 0 soft 1 temp 0.75 loss 3.66 helix 1.27 pae 0.30 i_pae 0.39 con 1.81 i_con 1.83 plddt 0.91 ptm 0.66 i_ptm 0.91 rg 0.73
# 82 models [4] recycles 1 hard 0 soft 1 temp 0.72 loss 5.07 helix 1.01 pae 0.43 i_pae 0.52 con 2.18 i_con 2.73 plddt 0.75 ptm 0.59 i_ptm 0.71 rg 0.67
# 83 models [3] recycles 1 hard 0 soft 1 temp 0.68 loss 5.66 helix 0.98 pae 0.46 i_pae 0.52 con 2.81 i_con 2.82 plddt 0.68 ptm 0.59 i_ptm 0.70 rg 0.13
# 84 models [2] recycles 1 hard 0 soft 1 temp 0.64 loss 4.06 helix 1.26 pae 0.33 i_pae 0.43 con 1.97 i_con 2.09 plddt 0.88 ptm 0.64 i_ptm 0.88 rg 0.60
# 85 models [2] recycles 1 hard 0 soft 1 temp 0.61 loss 3.53 helix 1.47 pae 0.33 i_pae 0.43 con 1.69 i_con 1.88 plddt 0.91 ptm 0.64 i_ptm 0.90 rg 0.68
# 86 models [1] recycles 1 hard 0 soft 1 temp 0.58 loss 3.62 helix 1.28 pae 0.30 i_pae 0.39 con 1.77 i_con 1.85 plddt 0.91 ptm 0.67 i_ptm 0.90 rg 0.72
# 87 models [4] recycles 1 hard 0 soft 1 temp 0.54 loss 3.96 helix 1.23 pae 0.31 i_pae 0.39 con 1.90 i_con 2.05 plddt 0.89 ptm 0.66 i_ptm 0.87 rg 0.69
# 88 models [0] recycles 1 hard 0 soft 1 temp 0.51 loss 3.67 helix 1.34 pae 0.30 i_pae 0.39 con 1.73 i_con 1.98 plddt 0.91 ptm 0.67 i_ptm 0.89 rg 0.61
# 89 models [1] recycles 1 hard 0 soft 1 temp 0.48 loss 3.64 helix 1.27 pae 0.31 i_pae 0.40 con 1.80 i_con 1.85 plddt 0.90 ptm 0.67 i_ptm 0.91 rg 0.64
# 90 models [0] recycles 1 hard 0 soft 1 temp 0.45 loss 5.94 helix 1.00 pae 0.43 i_pae 0.49 con 2.97 i_con 2.86 plddt 0.66 ptm 0.61 i_ptm 0.72 rg 0.48
# 91 models [3] recycles 1 hard 0 soft 1 temp 0.42 loss 3.14 helix 1.47 pae 0.29 i_pae 0.38 con 1.55 i_con 1.65 plddt 0.94 ptm 0.67 i_ptm 0.92 rg 0.74
# 92 models [2] recycles 1 hard 0 soft 1 temp 0.39 loss 3.22 helix 1.45 pae 0.30 i_pae 0.40 con 1.52 i_con 1.78 plddt 0.93 ptm 0.67 i_ptm 0.91 rg 0.61
# 93 models [1] recycles 1 hard 0 soft 1 temp 0.37 loss 5.07 helix 1.08 pae 0.39 i_pae 0.45 con 2.59 i_con 2.41 plddt 0.73 ptm 0.63 i_ptm 0.80 rg 0.50
# 94 models [0] recycles 1 hard 0 soft 1 temp 0.34 loss 5.17 helix 1.05 pae 0.38 i_pae 0.45 con 2.55 i_con 2.54 plddt 0.73 ptm 0.62 i_ptm 0.78 rg 0.55
# 95 models [1] recycles 1 hard 0 soft 1 temp 0.32 loss 5.21 helix 1.10 pae 0.40 i_pae 0.47 con 2.61 i_con 2.54 plddt 0.72 ptm 0.62 i_ptm 0.78 rg 0.49
# 96 models [1] recycles 1 hard 0 soft 1 temp 0.29 loss 3.42 helix 1.40 pae 0.30 i_pae 0.39 con 1.72 i_con 1.75 plddt 0.92 ptm 0.67 i_ptm 0.91 rg 0.66
# 97 models [1] recycles 1 hard 0 soft 1 temp 0.27 loss 4.95 helix 1.11 pae 0.37 i_pae 0.44 con 2.55 i_con 2.36 plddt 0.74 ptm 0.64 i_ptm 0.81 rg 0.50
# 98 models [3] recycles 1 hard 0 soft 1 temp 0.25 loss 5.01 helix 1.13 pae 0.39 i_pae 0.46 con 2.51 i_con 2.43 plddt 0.73 ptm 0.64 i_ptm 0.79 rg 0.58
# 99 models [3] recycles 1 hard 0 soft 1 temp 0.23 loss 5.56 helix 1.07 pae 0.43 i_pae 0.50 con 2.70 i_con 2.72 plddt 0.69 ptm 0.61 i_ptm 0.72 rg 0.63
# 100 models [2] recycles 1 hard 0 soft 1 temp 0.21 loss 3.43 helix 1.39 pae 0.32 i_pae 0.42 con 1.65 i_con 1.82 plddt 0.92 ptm 0.66 i_ptm 0.91 rg 0.66
# 101 models [1] recycles 1 hard 0 soft 1 temp 0.19 loss 5.16 helix 1.08 pae 0.39 i_pae 0.46 con 2.58 i_con 2.51 plddt 0.72 ptm 0.62 i_ptm 0.78 rg 0.51
# 102 models [3] recycles 1 hard 0 soft 1 temp 0.17 loss 4.34 helix 1.11 pae 0.33 i_pae 0.40 con 2.16 i_con 2.12 plddt 0.84 ptm 0.66 i_ptm 0.87 rg 0.64
# 103 models [4] recycles 1 hard 0 soft 1 temp 0.15 loss 8.11 helix 0.89 pae 0.73 i_pae 0.87 con 3.14 i_con 4.59 plddt 0.52 ptm 0.40 i_ptm 0.15 rg 0.61
# 104 models [0] recycles 1 hard 0 soft 1 temp 0.14 loss 4.05 helix 1.22 pae 0.31 i_pae 0.38 con 1.97 i_con 2.05 plddt 0.87 ptm 0.67 i_ptm 0.87 rg 0.70
# 105 models [4] recycles 1 hard 0 soft 1 temp 0.12 loss 4.70 helix 1.09 pae 0.35 i_pae 0.43 con 2.29 i_con 2.30 plddt 0.78 ptm 0.65 i_ptm 0.84 rg 0.75
# 106 models [4] recycles 1 hard 0 soft 1 temp 0.11 loss 4.54 helix 1.14 pae 0.34 i_pae 0.41 con 2.21 i_con 2.24 plddt 0.81 ptm 0.66 i_ptm 0.85 rg 0.79
# 107 models [4] recycles 1 hard 0 soft 1 temp 0.09 loss 4.20 helix 1.16 pae 0.32 i_pae 0.40 con 2.09 i_con 2.09 plddt 0.85 ptm 0.66 i_ptm 0.87 rg 0.60
# 108 models [3] recycles 1 hard 0 soft 1 temp 0.08 loss 3.86 helix 1.27 pae 0.30 i_pae 0.38 con 1.87 i_con 1.93 plddt 0.90 ptm 0.67 i_ptm 0.89 rg 0.86
# 109 models [3] recycles 1 hard 0 soft 1 temp 0.07 loss 5.45 helix 1.02 pae 0.43 i_pae 0.49 con 2.66 i_con 2.71 plddt 0.70 ptm 0.62 i_ptm 0.73 rg 0.43
# 110 models [2] recycles 1 hard 0 soft 1 temp 0.06 loss 5.65 helix 1.01 pae 0.46 i_pae 0.53 con 2.61 i_con 2.84 plddt 0.68 ptm 0.58 i_ptm 0.68 rg 0.72
# 111 models [2] recycles 1 hard 0 soft 1 temp 0.05 loss 6.53 helix 0.98 pae 0.58 i_pae 0.68 con 2.77 i_con 3.47 plddt 0.61 ptm 0.50 i_ptm 0.45 rg 0.71
# 112 models [4] recycles 1 hard 0 soft 1 temp 0.04 loss 3.58 helix 1.29 pae 0.30 i_pae 0.38 con 1.76 i_con 1.83 plddt 0.89 ptm 0.67 i_ptm 0.89 rg 0.69
# 113 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 6.53 helix 0.91 pae 0.53 i_pae 0.61 con 2.89 i_con 3.34 plddt 0.60 ptm 0.53 i_ptm 0.53 rg 0.75
# 114 models [3] recycles 1 hard 0 soft 1 temp 0.03 loss 3.23 helix 1.47 pae 0.28 i_pae 0.37 con 1.61 i_con 1.71 plddt 0.93 ptm 0.68 i_ptm 0.91 rg 0.61
# 115 models [0] recycles 1 hard 0 soft 1 temp 0.02 loss 7.95 helix 0.88 pae 0.72 i_pae 0.89 con 2.89 i_con 4.90 plddt 0.58 ptm 0.38 i_ptm 0.16 rg -0.12
# 116 models [4] recycles 1 hard 0 soft 1 temp 0.02 loss 5.89 helix 0.94 pae 0.48 i_pae 0.56 con 2.72 i_con 3.02 plddt 0.65 ptm 0.55 i_ptm 0.62 rg 0.44
# 117 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 6.67 helix 0.96 pae 0.61 i_pae 0.71 con 2.82 i_con 3.53 plddt 0.57 ptm 0.48 i_ptm 0.43 rg 0.74
# 118 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 6.81 helix 0.93 pae 0.59 i_pae 0.69 con 2.88 i_con 3.68 plddt 0.57 ptm 0.48 i_ptm 0.43 rg 0.51
# 119 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 5.21 helix 1.04 pae 0.42 i_pae 0.49 con 2.56 i_con 2.57 plddt 0.70 ptm 0.61 i_ptm 0.77 rg 0.44
# 120 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 3.52 helix 1.36 pae 0.32 i_pae 0.41 con 1.64 i_con 1.92 plddt 0.90 ptm 0.65 i_ptm 0.89 rg 0.63
# Softmax trajectory pLDDT good, continuing: 0.94
# Stage 3: One-hot Optimisation
# 121 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.19 helix 1.18 pae 0.30 i_pae 0.37 con 2.06 i_con 2.09 plddt 0.83 ptm 0.68 i_ptm 0.88 rg 0.72
# 122 models [3] recycles 1 hard 1 soft 1 temp 0.01 loss 2.99 helix 1.50 pae 0.26 i_pae 0.34 con 1.48 i_con 1.59 plddt 0.94 ptm 0.70 i_ptm 0.92 rg 0.76
# 123 models [1] recycles 1 hard 1 soft 1 temp 0.01 loss 3.47 helix 1.39 pae 0.28 i_pae 0.36 con 1.66 i_con 1.86 plddt 0.91 ptm 0.68 i_ptm 0.88 rg 0.69
# 124 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 5.19 helix 1.07 pae 0.37 i_pae 0.43 con 2.54 i_con 2.58 plddt 0.68 ptm 0.64 i_ptm 0.77 rg 0.49
# 125 models [3] recycles 1 hard 1 soft 1 temp 0.01 loss 3.03 helix 1.50 pae 0.26 i_pae 0.34 con 1.50 i_con 1.60 plddt 0.94 ptm 0.70 i_ptm 0.92 rg 0.78
# One-hot trajectory pLDDT good, continuing: 0.94
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [1] recycles 1 hard 1 soft 0 temp 1 loss 4.93 helix 1.08 pae 0.37 i_pae 0.43 con 2.48 i_con 2.39 plddt 0.69 ptm 0.64 i_ptm 0.80 rg 0.51
# 127 models [1] recycles 1 hard 1 soft 0 temp 1 loss 5.17 helix 1.04 pae 0.38 i_pae 0.44 con 2.56 i_con 2.52 plddt 0.68 ptm 0.63 i_ptm 0.77 rg 0.55
# 128 models [3] recycles 1 hard 1 soft 0 temp 1 loss 3.09 helix 1.39 pae 0.26 i_pae 0.34 con 1.51 i_con 1.62 plddt 0.94 ptm 0.69 i_ptm 0.92 rg 0.76
# 129 models [0] recycles 1 hard 1 soft 0 temp 1 loss 6.49 helix 0.78 pae 0.45 i_pae 0.53 con 3.02 i_con 3.24 plddt 0.60 ptm 0.57 i_ptm 0.59 rg 0.55
# 130 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.92 helix 0.87 pae 0.64 i_pae 0.71 con 3.50 i_con 3.76 plddt 0.43 ptm 0.49 i_ptm 0.39 rg 1.68
# 131 models [3] recycles 1 hard 1 soft 0 temp 1 loss 3.14 helix 1.37 pae 0.27 i_pae 0.35 con 1.53 i_con 1.65 plddt 0.94 ptm 0.69 i_ptm 0.91 rg 0.73
# 132 models [3] recycles 1 hard 1 soft 0 temp 1 loss 3.19 helix 1.33 pae 0.27 i_pae 0.35 con 1.54 i_con 1.68 plddt 0.94 ptm 0.69 i_ptm 0.91 rg 0.71
# 133 models [4] recycles 1 hard 1 soft 0 temp 1 loss 7.11 helix 0.77 pae 0.59 i_pae 0.66 con 3.02 i_con 3.47 plddt 0.49 ptm 0.52 i_ptm 0.46 rg 1.58
# 134 models [4] recycles 1 hard 1 soft 0 temp 1 loss 8.41 helix 0.69 pae 0.66 i_pae 0.75 con 3.61 i_con 3.98 plddt 0.43 ptm 0.47 i_ptm 0.32 rg 2.01
# 135 models [2] recycles 1 hard 1 soft 0 temp 1 loss 4.23 helix 0.99 pae 0.32 i_pae 0.40 con 1.98 i_con 2.15 plddt 0.86 ptm 0.66 i_ptm 0.87 rg 0.68
# 136 models [0] recycles 1 hard 1 soft 0 temp 1 loss 9.26 helix 0.58 pae 0.64 i_pae 0.74 con 3.66 i_con 4.11 plddt 0.44 ptm 0.47 i_ptm 0.31 rg 4.12
# 137 models [1] recycles 1 hard 1 soft 0 temp 1 loss 10.17 helix 0.57 pae 0.78 i_pae 0.92 con 3.82 i_con 5.04 plddt 0.42 ptm 0.41 i_ptm 0.11 rg 3.27
# 138 models [1] recycles 1 hard 1 soft 0 temp 1 loss 10.35 helix 0.53 pae 0.78 i_pae 0.94 con 3.74 i_con 5.21 plddt 0.47 ptm 0.40 i_ptm 0.11 rg 3.53
# 139 models [2] recycles 1 hard 1 soft 0 temp 1 loss 8.64 helix 0.62 pae 0.76 i_pae 0.93 con 3.09 i_con 4.88 plddt 0.54 ptm 0.41 i_ptm 0.11 rg 1.23
# 140 models [1] recycles 1 hard 1 soft 0 temp 1 loss 10.30 helix 0.54 pae 0.78 i_pae 0.93 con 3.78 i_con 5.15 plddt 0.45 ptm 0.40 i_ptm 0.10 rg 3.45
# Trajectory successful, final pLDDT: 0.94
# Starting trajectory took: 0 hours, 8 minutes, 12 seconds
#
# Fixing interface residues: B1,B2,B3,B4,B7,B8,B11,B14,B15,B18,B21,B23,B24,B26,B27,B30,B31,B34,B35,B38,B39,B41,B42,B45,B46,B48,B49,B50,B51,B53,B54,B57,B58,B60,B61,B64,B65,B67,B68,B71,B72,B73,B74,B75,B76,B77,B78,B79,B82
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn1, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn2, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn3, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn4, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn5, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn6, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn7, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn8, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn9, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn10, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn11, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn12, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn13, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn14, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn15, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn16, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn17, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn18, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn19, skipping interface scoring
# Base AF2 filters not passed for CTNI_l90_s547910_mpnn20, skipping interface scoring
# No accepted MPNN designs found for this trajectory.
# Design and validation of trajectory CTNI_l90_s547910 took: 0 hours, 1 minutes, 35 seconds
# Starting trajectory: CTNI_l148_s125068
# Stage 1: Test Logits
# 1 models [3] recycles 1 hard 0 soft 0.02 temp 1 loss 13.65 helix 1.53 pae 0.89 i_pae 0.94 con 4.53 i_con 4.96 plddt 0.29 ptm 0.38 i_ptm 0.11 rg 13.51
# 2 models [0] recycles 1 hard 0 soft 0.04 temp 1 loss 11.53 helix 1.21 pae 0.88 i_pae 0.96 con 4.35 i_con 5.53 plddt 0.32 ptm 0.34 i_ptm 0.09 rg 4.84
# 3 models [4] recycles 1 hard 0 soft 0.05 temp 1 loss 10.66 helix 0.76 pae 0.82 i_pae 0.89 con 4.25 i_con 4.81 plddt 0.36 ptm 0.36 i_ptm 0.14 rg 4.37
# 4 models [0] recycles 1 hard 0 soft 0.07 temp 1 loss 10.37 helix 0.72 pae 0.83 i_pae 0.95 con 3.92 i_con 5.77 plddt 0.40 ptm 0.34 i_ptm 0.10 rg 1.22
# 5 models [0] recycles 1 hard 0 soft 0.09 temp 1 loss 10.82 helix 0.74 pae 0.84 i_pae 0.96 con 3.91 i_con 5.62 plddt 0.41 ptm 0.34 i_ptm 0.08 rg 3.25
# 6 models [3] recycles 1 hard 0 soft 0.11 temp 1 loss 10.21 helix 0.76 pae 0.79 i_pae 0.94 con 3.78 i_con 5.35 plddt 0.45 ptm 0.36 i_ptm 0.11 rg 2.69
# 7 models [4] recycles 1 hard 0 soft 0.13 temp 1 loss 9.96 helix 0.71 pae 0.79 i_pae 0.94 con 3.68 i_con 5.44 plddt 0.44 ptm 0.33 i_ptm 0.11 rg 1.80
# 8 models [4] recycles 1 hard 0 soft 0.14 temp 1 loss 9.91 helix 0.77 pae 0.82 i_pae 0.95 con 3.65 i_con 5.22 plddt 0.43 ptm 0.33 i_ptm 0.10 rg 2.46
# 9 models [1] recycles 1 hard 0 soft 0.16 temp 1 loss 9.89 helix 0.92 pae 0.83 i_pae 0.94 con 3.71 i_con 5.29 plddt 0.42 ptm 0.34 i_ptm 0.10 rg 2.13
# 10 models [3] recycles 1 hard 0 soft 0.18 temp 1 loss 8.97 helix 0.97 pae 0.80 i_pae 0.89 con 3.61 i_con 4.80 plddt 0.42 ptm 0.37 i_ptm 0.13 rg 1.17
# 11 models [4] recycles 1 hard 0 soft 0.20 temp 1 loss 9.02 helix 0.85 pae 0.80 i_pae 0.92 con 3.53 i_con 4.98 plddt 0.42 ptm 0.35 i_ptm 0.11 rg 0.83
# 12 models [0] recycles 1 hard 0 soft 0.22 temp 1 loss 9.00 helix 0.87 pae 0.78 i_pae 0.94 con 3.29 i_con 5.45 plddt 0.48 ptm 0.33 i_ptm 0.10 rg 0.05
# 13 models [2] recycles 1 hard 0 soft 0.23 temp 1 loss 8.41 helix 0.83 pae 0.74 i_pae 0.91 con 3.24 i_con 5.02 plddt 0.49 ptm 0.32 i_ptm 0.12 rg -0.27
# 14 models [4] recycles 1 hard 0 soft 0.25 temp 1 loss 8.16 helix 0.90 pae 0.75 i_pae 0.88 con 3.30 i_con 4.79 plddt 0.45 ptm 0.37 i_ptm 0.17 rg -0.48
# 15 models [1] recycles 1 hard 0 soft 0.27 temp 1 loss 8.13 helix 0.91 pae 0.68 i_pae 0.83 con 3.11 i_con 4.72 plddt 0.53 ptm 0.39 i_ptm 0.22 rg 0.47
# 16 models [4] recycles 1 hard 0 soft 0.29 temp 1 loss 7.76 helix 0.95 pae 0.66 i_pae 0.84 con 2.90 i_con 4.69 plddt 0.54 ptm 0.40 i_ptm 0.21 rg 0.07
# 17 models [4] recycles 1 hard 0 soft 0.31 temp 1 loss 7.50 helix 0.97 pae 0.61 i_pae 0.79 con 2.79 i_con 4.54 plddt 0.56 ptm 0.43 i_ptm 0.28 rg 0.19
# 18 models [4] recycles 1 hard 0 soft 0.32 temp 1 loss 7.50 helix 1.05 pae 0.59 i_pae 0.80 con 2.63 i_con 4.71 plddt 0.63 ptm 0.42 i_ptm 0.26 rg 0.29
# 19 models [4] recycles 1 hard 0 soft 0.34 temp 1 loss 6.61 helix 1.14 pae 0.48 i_pae 0.66 con 2.38 i_con 4.09 plddt 0.63 ptm 0.51 i_ptm 0.47 rg 0.54
# 20 models [0] recycles 1 hard 0 soft 0.36 temp 1 loss 5.96 helix 1.20 pae 0.41 i_pae 0.55 con 2.29 i_con 3.72 plddt 0.67 ptm 0.56 i_ptm 0.61 rg 0.12
# 21 models [4] recycles 1 hard 0 soft 0.38 temp 1 loss 5.68 helix 1.29 pae 0.38 i_pae 0.52 con 2.15 i_con 3.57 plddt 0.64 ptm 0.61 i_ptm 0.69 rg 0.29
# 22 models [3] recycles 1 hard 0 soft 0.40 temp 1 loss 6.66 helix 1.10 pae 0.49 i_pae 0.66 con 2.44 i_con 3.98 plddt 0.64 ptm 0.53 i_ptm 0.50 rg 0.81
# 23 models [0] recycles 1 hard 0 soft 0.41 temp 1 loss 5.72 helix 1.20 pae 0.38 i_pae 0.49 con 2.34 i_con 3.47 plddt 0.63 ptm 0.62 i_ptm 0.70 rg 0.03
# 24 models [2] recycles 1 hard 0 soft 0.43 temp 1 loss 5.72 helix 1.16 pae 0.41 i_pae 0.57 con 2.14 i_con 3.52 plddt 0.67 ptm 0.58 i_ptm 0.63 rg 0.44
# 25 models [2] recycles 1 hard 0 soft 0.45 temp 1 loss 6.10 helix 1.17 pae 0.45 i_pae 0.61 con 2.18 i_con 3.64 plddt 0.65 ptm 0.52 i_ptm 0.53 rg 1.12
# 26 models [2] recycles 1 hard 0 soft 0.47 temp 1 loss 5.57 helix 1.23 pae 0.39 i_pae 0.52 con 2.26 i_con 3.38 plddt 0.64 ptm 0.61 i_ptm 0.71 rg 0.14
# 27 models [2] recycles 1 hard 0 soft 0.49 temp 1 loss 5.40 helix 1.27 pae 0.38 i_pae 0.52 con 2.17 i_con 3.32 plddt 0.68 ptm 0.61 i_ptm 0.72 rg 0.14
# 28 models [0] recycles 1 hard 0 soft 0.50 temp 1 loss 5.53 helix 1.27 pae 0.38 i_pae 0.51 con 2.27 i_con 3.40 plddt 0.65 ptm 0.60 i_ptm 0.69 rg -0.05
# 29 models [2] recycles 1 hard 0 soft 0.52 temp 1 loss 5.10 helix 1.25 pae 0.36 i_pae 0.49 con 2.12 i_con 3.17 plddt 0.68 ptm 0.63 i_ptm 0.74 rg -0.17
# 30 models [4] recycles 1 hard 0 soft 0.54 temp 1 loss 4.89 helix 1.34 pae 0.34 i_pae 0.46 con 2.08 i_con 3.16 plddt 0.64 ptm 0.65 i_ptm 0.76 rg -0.59
# 31 models [1] recycles 1 hard 0 soft 0.56 temp 1 loss 5.16 helix 1.31 pae 0.34 i_pae 0.46 con 2.15 i_con 3.13 plddt 0.64 ptm 0.64 i_ptm 0.76 rg 0.13
# 32 models [4] recycles 1 hard 0 soft 0.58 temp 1 loss 4.62 helix 1.31 pae 0.32 i_pae 0.44 con 2.01 i_con 2.97 plddt 0.66 ptm 0.66 i_ptm 0.77 rg -0.64
# 33 models [1] recycles 1 hard 0 soft 0.59 temp 1 loss 4.72 helix 1.42 pae 0.32 i_pae 0.44 con 2.11 i_con 2.96 plddt 0.64 ptm 0.67 i_ptm 0.80 rg -0.49
# 34 models [0] recycles 1 hard 0 soft 0.61 temp 1 loss 4.95 helix 1.30 pae 0.33 i_pae 0.44 con 2.07 i_con 2.94 plddt 0.63 ptm 0.65 i_ptm 0.76 rg 0.35
# 35 models [1] recycles 1 hard 0 soft 0.63 temp 1 loss 4.94 helix 1.27 pae 0.34 i_pae 0.45 con 2.11 i_con 2.99 plddt 0.66 ptm 0.67 i_ptm 0.79 rg -0.00
# 36 models [0] recycles 1 hard 0 soft 0.65 temp 1 loss 5.03 helix 1.31 pae 0.35 i_pae 0.46 con 2.15 i_con 3.03 plddt 0.68 ptm 0.65 i_ptm 0.76 rg 0.06
# 37 models [3] recycles 1 hard 0 soft 0.67 temp 1 loss 7.10 helix 1.07 pae 0.57 i_pae 0.81 con 2.44 i_con 4.55 plddt 0.72 ptm 0.39 i_ptm 0.21 rg 0.19
# 38 models [3] recycles 1 hard 0 soft 0.68 temp 1 loss 6.38 helix 1.13 pae 0.49 i_pae 0.70 con 2.22 i_con 4.06 plddt 0.77 ptm 0.46 i_ptm 0.36 rg 0.39
# 39 models [1] recycles 1 hard 0 soft 0.70 temp 1 loss 5.37 helix 1.18 pae 0.37 i_pae 0.51 con 2.23 i_con 3.40 plddt 0.62 ptm 0.60 i_ptm 0.70 rg -0.50
# 40 models [4] recycles 1 hard 0 soft 0.72 temp 1 loss 5.14 helix 1.22 pae 0.37 i_pae 0.52 con 2.09 i_con 3.24 plddt 0.63 ptm 0.61 i_ptm 0.69 rg -0.24
# 41 models [3] recycles 1 hard 0 soft 0.74 temp 1 loss 4.74 helix 1.32 pae 0.31 i_pae 0.42 con 1.98 i_con 2.99 plddt 0.72 ptm 0.68 i_ptm 0.78 rg -0.15
# 42 models [2] recycles 1 hard 0 soft 0.76 temp 1 loss 4.71 helix 1.25 pae 0.35 i_pae 0.48 con 2.02 i_con 3.02 plddt 0.70 ptm 0.62 i_ptm 0.75 rg -0.59
# 43 models [0] recycles 1 hard 0 soft 0.77 temp 1 loss 4.44 helix 1.32 pae 0.31 i_pae 0.43 con 1.91 i_con 2.82 plddt 0.72 ptm 0.66 i_ptm 0.79 rg -0.34
# 44 models [1] recycles 1 hard 0 soft 0.79 temp 1 loss 4.79 helix 1.23 pae 0.32 i_pae 0.43 con 2.08 i_con 2.89 plddt 0.64 ptm 0.67 i_ptm 0.79 rg -0.08
# 45 models [2] recycles 1 hard 0 soft 0.81 temp 1 loss 4.17 helix 1.40 pae 0.30 i_pae 0.42 con 1.87 i_con 2.69 plddt 0.73 ptm 0.68 i_ptm 0.82 rg -0.52
# 46 models [3] recycles 1 hard 0 soft 0.83 temp 1 loss 6.43 helix 1.20 pae 0.52 i_pae 0.77 con 2.10 i_con 4.31 plddt 0.79 ptm 0.44 i_ptm 0.25 rg 0.09
# 47 models [2] recycles 1 hard 0 soft 0.85 temp 1 loss 5.14 helix 1.22 pae 0.37 i_pae 0.51 con 2.03 i_con 3.12 plddt 0.84 ptm 0.59 i_ptm 0.64 rg 0.41
# 48 models [2] recycles 1 hard 0 soft 0.86 temp 1 loss 5.51 helix 1.21 pae 0.40 i_pae 0.56 con 2.03 i_con 3.45 plddt 0.82 ptm 0.54 i_ptm 0.55 rg 0.46
# 49 models [2] recycles 1 hard 0 soft 0.88 temp 1 loss 5.14 helix 1.20 pae 0.37 i_pae 0.52 con 1.97 i_con 3.17 plddt 0.83 ptm 0.57 i_ptm 0.63 rg 0.41
# 50 models [3] recycles 1 hard 0 soft 0.90 temp 1 loss 8.09 helix 0.95 pae 0.75 i_pae 0.90 con 2.98 i_con 4.88 plddt 0.50 ptm 0.36 i_ptm 0.12 rg 0.09
# Initial trajectory pLDDT good, continuing: 0.73
# Stage 1: Additional Logits Optimisation
# 51 models [2] recycles 1 hard 0 soft 0.04 temp 1 loss 9.58 helix 1.47 pae 0.89 i_pae 0.97 con 4.23 i_con 5.22 plddt 0.25 ptm 0.16 i_ptm 0.08 rg -0.00
# 52 models [3] recycles 1 hard 0 soft 0.08 temp 1 loss 8.26 helix 1.05 pae 0.74 i_pae 0.89 con 2.95 i_con 5.01 plddt 0.51 ptm 0.38 i_ptm 0.12 rg 0.45
# 53 models [3] recycles 1 hard 0 soft 0.12 temp 1 loss 5.70 helix 1.24 pae 0.43 i_pae 0.62 con 1.94 i_con 3.71 plddt 0.83 ptm 0.52 i_ptm 0.46 rg 0.48
# 54 models [1] recycles 1 hard 0 soft 0.16 temp 1 loss 8.57 helix 1.05 pae 0.77 i_pae 0.90 con 3.31 i_con 4.99 plddt 0.46 ptm 0.36 i_ptm 0.12 rg 0.29
# 55 models [3] recycles 1 hard 0 soft 0.20 temp 1 loss 8.72 helix 1.09 pae 0.78 i_pae 0.93 con 3.27 i_con 5.21 plddt 0.44 ptm 0.36 i_ptm 0.10 rg 0.24
# 56 models [0] recycles 1 hard 0 soft 0.24 temp 1 loss 7.75 helix 1.21 pae 0.64 i_pae 0.89 con 2.41 i_con 5.23 plddt 0.70 ptm 0.37 i_ptm 0.12 rg 0.18
# 57 models [1] recycles 1 hard 0 soft 0.28 temp 1 loss 6.17 helix 1.25 pae 0.47 i_pae 0.63 con 2.29 i_con 3.82 plddt 0.76 ptm 0.51 i_ptm 0.47 rg 0.45
# 58 models [4] recycles 1 hard 0 soft 0.32 temp 1 loss 5.32 helix 1.28 pae 0.36 i_pae 0.49 con 2.13 i_con 3.21 plddt 0.83 ptm 0.61 i_ptm 0.64 rg 0.44
# 59 models [2] recycles 1 hard 0 soft 0.36 temp 1 loss 4.64 helix 1.44 pae 0.33 i_pae 0.46 con 1.84 i_con 2.88 plddt 0.88 ptm 0.65 i_ptm 0.72 rg 0.51
# 60 models [4] recycles 1 hard 0 soft 0.40 temp 1 loss 4.86 helix 1.38 pae 0.35 i_pae 0.49 con 1.92 i_con 3.20 plddt 0.65 ptm 0.62 i_ptm 0.68 rg -0.29
# 61 models [2] recycles 1 hard 0 soft 0.44 temp 1 loss 4.46 helix 1.43 pae 0.31 i_pae 0.43 con 1.88 i_con 2.67 plddt 0.87 ptm 0.67 i_ptm 0.78 rg 0.49
# 62 models [4] recycles 1 hard 0 soft 0.48 temp 1 loss 4.23 helix 1.51 pae 0.29 i_pae 0.41 con 1.75 i_con 2.61 plddt 0.89 ptm 0.69 i_ptm 0.79 rg 0.49
# 63 models [0] recycles 1 hard 0 soft 0.52 temp 1 loss 4.29 helix 1.43 pae 0.30 i_pae 0.42 con 1.82 i_con 2.78 plddt 0.74 ptm 0.67 i_ptm 0.81 rg -0.29
# 64 models [4] recycles 1 hard 0 soft 0.56 temp 1 loss 4.45 helix 1.43 pae 0.31 i_pae 0.44 con 1.78 i_con 2.87 plddt 0.69 ptm 0.67 i_ptm 0.79 rg 0.09
# 65 models [3] recycles 1 hard 0 soft 0.60 temp 1 loss 4.72 helix 1.40 pae 0.33 i_pae 0.47 con 1.80 i_con 2.99 plddt 0.87 ptm 0.65 i_ptm 0.72 rg 0.47
# 66 models [3] recycles 1 hard 0 soft 0.64 temp 1 loss 4.28 helix 1.46 pae 0.29 i_pae 0.41 con 1.77 i_con 2.81 plddt 0.74 ptm 0.68 i_ptm 0.79 rg -0.19
# 67 models [3] recycles 1 hard 0 soft 0.68 temp 1 loss 4.37 helix 1.44 pae 0.30 i_pae 0.43 con 1.70 i_con 2.77 plddt 0.89 ptm 0.67 i_ptm 0.77 rg 0.48
# 68 models [3] recycles 1 hard 0 soft 0.72 temp 1 loss 4.16 helix 1.42 pae 0.28 i_pae 0.40 con 1.73 i_con 2.55 plddt 0.89 ptm 0.68 i_ptm 0.78 rg 0.42
# 69 models [3] recycles 1 hard 0 soft 0.76 temp 1 loss 4.12 helix 1.49 pae 0.27 i_pae 0.38 con 1.66 i_con 2.57 plddt 0.90 ptm 0.71 i_ptm 0.78 rg 0.54
# 70 models [3] recycles 1 hard 0 soft 0.80 temp 1 loss 4.14 helix 1.48 pae 0.28 i_pae 0.40 con 1.70 i_con 2.57 plddt 0.90 ptm 0.69 i_ptm 0.80 rg 0.48
# 71 models [4] recycles 1 hard 0 soft 0.84 temp 1 loss 4.21 helix 1.44 pae 0.29 i_pae 0.40 con 1.74 i_con 2.55 plddt 0.89 ptm 0.68 i_ptm 0.78 rg 0.56
# 72 models [1] recycles 1 hard 0 soft 0.88 temp 1 loss 8.61 helix 1.05 pae 0.77 i_pae 0.89 con 3.41 i_con 4.92 plddt 0.43 ptm 0.36 i_ptm 0.13 rg 0.28
# 73 models [1] recycles 1 hard 0 soft 0.92 temp 1 loss 8.70 helix 0.97 pae 0.77 i_pae 0.88 con 3.51 i_con 4.79 plddt 0.43 ptm 0.37 i_ptm 0.15 rg 0.63
# 74 models [4] recycles 1 hard 0 soft 0.96 temp 1 loss 8.78 helix 0.92 pae 0.79 i_pae 0.91 con 3.19 i_con 4.94 plddt 0.47 ptm 0.34 i_ptm 0.11 rg 1.43
# 75 models [1] recycles 1 hard 0 soft 1 temp 1 loss 9.23 helix 0.94 pae 0.76 i_pae 0.85 con 3.50 i_con 4.70 plddt 0.43 ptm 0.37 i_ptm 0.18 rg 2.76
# Optimised logit trajectory pLDDT: 0.9
# Stage 2: Softmax Optimisation
# 76 models [2] recycles 1 hard 0 soft 1 temp 0.96 loss 8.44 helix 0.86 pae 0.77 i_pae 0.90 con 3.19 i_con 4.87 plddt 0.47 ptm 0.34 i_ptm 0.13 rg 0.50
# 77 models [0] recycles 1 hard 0 soft 1 temp 0.91 loss 8.15 helix 0.90 pae 0.73 i_pae 0.90 con 2.85 i_con 5.21 plddt 0.54 ptm 0.35 i_ptm 0.12 rg -0.37
# 78 models [0] recycles 1 hard 0 soft 1 temp 0.87 loss 6.69 helix 1.04 pae 0.53 i_pae 0.74 con 2.25 i_con 4.28 plddt 0.73 ptm 0.43 i_ptm 0.33 rg 0.40
# 79 models [3] recycles 1 hard 0 soft 1 temp 0.83 loss 5.60 helix 1.10 pae 0.41 i_pae 0.55 con 2.21 i_con 3.38 plddt 0.78 ptm 0.58 i_ptm 0.62 rg 0.29
# 80 models [3] recycles 1 hard 0 soft 1 temp 0.79 loss 5.12 helix 1.22 pae 0.36 i_pae 0.48 con 2.09 i_con 3.07 plddt 0.82 ptm 0.62 i_ptm 0.70 rg 0.33
# 81 models [1] recycles 1 hard 0 soft 1 temp 0.75 loss 7.64 helix 1.07 pae 0.64 i_pae 0.87 con 2.55 i_con 4.91 plddt 0.64 ptm 0.37 i_ptm 0.14 rg 0.24
# 82 models [3] recycles 1 hard 0 soft 1 temp 0.72 loss 4.84 helix 1.30 pae 0.33 i_pae 0.46 con 1.95 i_con 2.94 plddt 0.85 ptm 0.64 i_ptm 0.73 rg 0.46
# 83 models [4] recycles 1 hard 0 soft 1 temp 0.68 loss 4.66 helix 1.33 pae 0.31 i_pae 0.44 con 1.87 i_con 2.86 plddt 0.86 ptm 0.65 i_ptm 0.75 rg 0.43
# 84 models [4] recycles 1 hard 0 soft 1 temp 0.64 loss 8.51 helix 0.96 pae 0.73 i_pae 0.87 con 2.83 i_con 4.75 plddt 0.54 ptm 0.37 i_ptm 0.15 rg 2.51
# 85 models [0] recycles 1 hard 0 soft 1 temp 0.61 loss 4.94 helix 1.26 pae 0.32 i_pae 0.44 con 1.99 i_con 2.94 plddt 0.83 ptm 0.62 i_ptm 0.71 rg 0.60
# 86 models [2] recycles 1 hard 0 soft 1 temp 0.58 loss 4.95 helix 1.23 pae 0.33 i_pae 0.45 con 2.02 i_con 2.92 plddt 0.84 ptm 0.62 i_ptm 0.70 rg 0.56
# 87 models [4] recycles 1 hard 0 soft 1 temp 0.54 loss 4.76 helix 1.31 pae 0.33 i_pae 0.46 con 1.88 i_con 2.93 plddt 0.86 ptm 0.64 i_ptm 0.74 rg 0.47
# 88 models [3] recycles 1 hard 0 soft 1 temp 0.51 loss 6.02 helix 1.13 pae 0.44 i_pae 0.57 con 2.38 i_con 3.60 plddt 0.75 ptm 0.55 i_ptm 0.52 rg 0.31
# 89 models [4] recycles 1 hard 0 soft 1 temp 0.48 loss 6.26 helix 1.19 pae 0.50 i_pae 0.67 con 2.14 i_con 4.03 plddt 0.75 ptm 0.47 i_ptm 0.40 rg 0.43
# 90 models [2] recycles 1 hard 0 soft 1 temp 0.45 loss 5.89 helix 1.20 pae 0.45 i_pae 0.61 con 2.19 i_con 3.66 plddt 0.77 ptm 0.52 i_ptm 0.53 rg 0.39
# 91 models [2] recycles 1 hard 0 soft 1 temp 0.42 loss 5.53 helix 1.23 pae 0.41 i_pae 0.54 con 2.10 i_con 3.41 plddt 0.79 ptm 0.58 i_ptm 0.60 rg 0.45
# 92 models [1] recycles 1 hard 0 soft 1 temp 0.39 loss 4.71 helix 1.38 pae 0.32 i_pae 0.45 con 1.91 i_con 2.84 plddt 0.86 ptm 0.65 i_ptm 0.75 rg 0.59
# 93 models [4] recycles 1 hard 0 soft 1 temp 0.37 loss 6.17 helix 1.14 pae 0.47 i_pae 0.61 con 2.38 i_con 3.70 plddt 0.74 ptm 0.52 i_ptm 0.50 rg 0.45
# 94 models [0] recycles 1 hard 0 soft 1 temp 0.34 loss 4.92 helix 1.22 pae 0.31 i_pae 0.42 con 2.09 i_con 2.81 plddt 0.83 ptm 0.63 i_ptm 0.73 rg 0.61
# 95 models [3] recycles 1 hard 0 soft 1 temp 0.32 loss 4.81 helix 1.32 pae 0.32 i_pae 0.45 con 1.88 i_con 2.96 plddt 0.88 ptm 0.63 i_ptm 0.71 rg 0.58
# 96 models [3] recycles 1 hard 0 soft 1 temp 0.29 loss 4.45 helix 1.44 pae 0.30 i_pae 0.42 con 1.82 i_con 2.72 plddt 0.89 ptm 0.66 i_ptm 0.76 rg 0.50
# 97 models [0] recycles 1 hard 0 soft 1 temp 0.27 loss 4.54 helix 1.41 pae 0.30 i_pae 0.42 con 1.86 i_con 2.73 plddt 0.87 ptm 0.65 i_ptm 0.73 rg 0.61
# 98 models [1] recycles 1 hard 0 soft 1 temp 0.25 loss 4.72 helix 1.38 pae 0.32 i_pae 0.44 con 1.90 i_con 2.90 plddt 0.85 ptm 0.63 i_ptm 0.72 rg 0.45
# 99 models [1] recycles 1 hard 0 soft 1 temp 0.23 loss 4.34 helix 1.45 pae 0.28 i_pae 0.40 con 1.85 i_con 2.59 plddt 0.88 ptm 0.67 i_ptm 0.79 rg 0.54
# 100 models [2] recycles 1 hard 0 soft 1 temp 0.21 loss 4.55 helix 1.36 pae 0.32 i_pae 0.45 con 1.87 i_con 2.76 plddt 0.87 ptm 0.63 i_ptm 0.73 rg 0.45
# 101 models [4] recycles 1 hard 0 soft 1 temp 0.19 loss 4.52 helix 1.32 pae 0.29 i_pae 0.40 con 1.95 i_con 2.65 plddt 0.87 ptm 0.66 i_ptm 0.76 rg 0.47
# 102 models [1] recycles 1 hard 0 soft 1 temp 0.17 loss 5.33 helix 1.28 pae 0.37 i_pae 0.46 con 2.39 i_con 2.91 plddt 0.74 ptm 0.64 i_ptm 0.70 rg 0.59
# 103 models [3] recycles 1 hard 0 soft 1 temp 0.15 loss 4.40 helix 1.40 pae 0.28 i_pae 0.39 con 1.88 i_con 2.60 plddt 0.88 ptm 0.67 i_ptm 0.78 rg 0.57
# 104 models [0] recycles 1 hard 0 soft 1 temp 0.14 loss 4.36 helix 1.43 pae 0.29 i_pae 0.40 con 1.87 i_con 2.60 plddt 0.87 ptm 0.67 i_ptm 0.78 rg 0.44
# 105 models [0] recycles 1 hard 0 soft 1 temp 0.12 loss 5.77 helix 1.04 pae 0.39 i_pae 0.49 con 2.50 i_con 3.15 plddt 0.73 ptm 0.59 i_ptm 0.65 rg 0.59
# 106 models [0] recycles 1 hard 0 soft 1 temp 0.11 loss 4.37 helix 1.37 pae 0.29 i_pae 0.41 con 1.85 i_con 2.60 plddt 0.87 ptm 0.66 i_ptm 0.78 rg 0.48
# 107 models [3] recycles 1 hard 0 soft 1 temp 0.09 loss 6.21 helix 0.99 pae 0.46 i_pae 0.58 con 2.51 i_con 3.57 plddt 0.71 ptm 0.55 i_ptm 0.52 rg 0.44
# 108 models [2] recycles 1 hard 0 soft 1 temp 0.08 loss 4.97 helix 1.25 pae 0.34 i_pae 0.47 con 2.06 i_con 2.90 plddt 0.84 ptm 0.61 i_ptm 0.69 rg 0.56
# 109 models [3] recycles 1 hard 0 soft 1 temp 0.07 loss 4.51 helix 1.32 pae 0.30 i_pae 0.42 con 1.89 i_con 2.68 plddt 0.88 ptm 0.65 i_ptm 0.75 rg 0.46
# 110 models [0] recycles 1 hard 0 soft 1 temp 0.06 loss 4.35 helix 1.37 pae 0.29 i_pae 0.40 con 1.84 i_con 2.59 plddt 0.87 ptm 0.68 i_ptm 0.77 rg 0.48
# 111 models [0] recycles 1 hard 0 soft 1 temp 0.05 loss 4.59 helix 1.36 pae 0.30 i_pae 0.41 con 1.88 i_con 2.76 plddt 0.86 ptm 0.66 i_ptm 0.76 rg 0.59
# 112 models [1] recycles 1 hard 0 soft 1 temp 0.04 loss 4.40 helix 1.44 pae 0.29 i_pae 0.41 con 1.80 i_con 2.67 plddt 0.88 ptm 0.67 i_ptm 0.76 rg 0.59
# 113 models [4] recycles 1 hard 0 soft 1 temp 0.03 loss 5.66 helix 1.18 pae 0.40 i_pae 0.55 con 2.07 i_con 3.61 plddt 0.64 ptm 0.61 i_ptm 0.66 rg 0.22
# 114 models [4] recycles 1 hard 0 soft 1 temp 0.03 loss 5.86 helix 1.20 pae 0.44 i_pae 0.62 con 2.07 i_con 3.72 plddt 0.80 ptm 0.54 i_ptm 0.51 rg 0.47
# 115 models [4] recycles 1 hard 0 soft 1 temp 0.02 loss 5.11 helix 1.25 pae 0.36 i_pae 0.50 con 2.01 i_con 3.10 plddt 0.82 ptm 0.59 i_ptm 0.65 rg 0.48
# 116 models [1] recycles 1 hard 0 soft 1 temp 0.02 loss 4.39 helix 1.42 pae 0.29 i_pae 0.41 con 1.81 i_con 2.66 plddt 0.88 ptm 0.67 i_ptm 0.76 rg 0.56
# 117 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.52 helix 1.35 pae 0.29 i_pae 0.40 con 1.88 i_con 2.69 plddt 0.87 ptm 0.67 i_ptm 0.77 rg 0.56
# 118 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.65 helix 1.32 pae 0.30 i_pae 0.41 con 1.95 i_con 2.73 plddt 0.85 ptm 0.65 i_ptm 0.76 rg 0.57
# 119 models [1] recycles 1 hard 0 soft 1 temp 0.01 loss 4.43 helix 1.33 pae 0.30 i_pae 0.41 con 1.86 i_con 2.61 plddt 0.87 ptm 0.67 i_ptm 0.77 rg 0.55
# 120 models [2] recycles 1 hard 0 soft 1 temp 0.01 loss 4.86 helix 1.25 pae 0.34 i_pae 0.46 con 1.95 i_con 2.90 plddt 0.85 ptm 0.63 i_ptm 0.73 rg 0.62
# Softmax trajectory pLDDT good, continuing: 0.88
# Stage 3: One-hot Optimisation
# 121 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.55 helix 1.29 pae 0.29 i_pae 0.40 con 1.89 i_con 2.71 plddt 0.83 ptm 0.67 i_ptm 0.75 rg 0.53
# 122 models [2] recycles 1 hard 1 soft 1 temp 0.01 loss 4.50 helix 1.37 pae 0.29 i_pae 0.40 con 1.84 i_con 2.71 plddt 0.86 ptm 0.67 i_ptm 0.78 rg 0.59
# 123 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.56 helix 1.31 pae 0.29 i_pae 0.40 con 1.89 i_con 2.70 plddt 0.83 ptm 0.67 i_ptm 0.75 rg 0.59
# 124 models [4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.58 helix 1.30 pae 0.30 i_pae 0.40 con 1.89 i_con 2.72 plddt 0.83 ptm 0.67 i_ptm 0.75 rg 0.58
# 125 models [0] recycles 1 hard 1 soft 1 temp 0.01 loss 4.75 helix 1.28 pae 0.30 i_pae 0.41 con 1.94 i_con 2.83 plddt 0.84 ptm 0.65 i_ptm 0.73 rg 0.59
# One-hot trajectory pLDDT good, continuing: 0.86
# Stage 4: PSSM Semigreedy Optimisation
# Running semigreedy optimization...
# 126 models [2] recycles 1 hard 1 soft 0 temp 1 loss 5.23 helix 1.16 pae 0.36 i_pae 0.48 con 1.98 i_con 3.23 plddt 0.79 ptm 0.62 i_ptm 0.64 rg 0.45
# 127 models [0] recycles 1 hard 1 soft 0 temp 1 loss 4.83 helix 1.22 pae 0.31 i_pae 0.42 con 1.93 i_con 2.90 plddt 0.82 ptm 0.63 i_ptm 0.69 rg 0.53
# 128 models [3] recycles 1 hard 1 soft 0 temp 1 loss 5.05 helix 1.13 pae 0.32 i_pae 0.43 con 2.08 i_con 2.94 plddt 0.81 ptm 0.65 i_ptm 0.70 rg 0.55
# 129 models [4] recycles 1 hard 1 soft 0 temp 1 loss 4.87 helix 1.19 pae 0.32 i_pae 0.42 con 1.96 i_con 2.91 plddt 0.80 ptm 0.65 i_ptm 0.70 rg 0.50
# 130 models [4] recycles 1 hard 1 soft 0 temp 1 loss 4.78 helix 1.16 pae 0.31 i_pae 0.41 con 1.96 i_con 2.82 plddt 0.81 ptm 0.66 i_ptm 0.73 rg 0.48
# 131 models [3] recycles 1 hard 1 soft 0 temp 1 loss 4.91 helix 1.15 pae 0.31 i_pae 0.41 con 2.04 i_con 2.84 plddt 0.82 ptm 0.65 i_ptm 0.73 rg 0.58
# 132 models [0] recycles 1 hard 1 soft 0 temp 1 loss 4.92 helix 1.16 pae 0.30 i_pae 0.41 con 2.03 i_con 2.86 plddt 0.81 ptm 0.65 i_ptm 0.73 rg 0.60
# 133 models [2] recycles 1 hard 1 soft 0 temp 1 loss 5.16 helix 1.11 pae 0.34 i_pae 0.45 con 2.07 i_con 3.05 plddt 0.80 ptm 0.63 i_ptm 0.68 rg 0.52
# 134 models [4] recycles 1 hard 1 soft 0 temp 1 loss 4.79 helix 1.18 pae 0.31 i_pae 0.41 con 1.97 i_con 2.83 plddt 0.80 ptm 0.66 i_ptm 0.73 rg 0.47
# 135 models [0] recycles 1 hard 1 soft 0 temp 1 loss 5.06 helix 1.09 pae 0.31 i_pae 0.41 con 2.18 i_con 2.84 plddt 0.79 ptm 0.66 i_ptm 0.75 rg 0.52
# 136 models [3] recycles 1 hard 1 soft 0 temp 1 loss 5.00 helix 1.11 pae 0.32 i_pae 0.42 con 2.08 i_con 2.88 plddt 0.80 ptm 0.65 i_ptm 0.71 rg 0.55
# 137 models [3] recycles 1 hard 1 soft 0 temp 1 loss 5.02 helix 1.10 pae 0.32 i_pae 0.42 con 2.09 i_con 2.90 plddt 0.80 ptm 0.65 i_ptm 0.71 rg 0.54
# 138 models [3] recycles 1 hard 1 soft 0 temp 1 loss 4.89 helix 1.11 pae 0.31 i_pae 0.41 con 2.05 i_con 2.82 plddt 0.81 ptm 0.67 i_ptm 0.74 rg 0.54
# 139 models [0] recycles 1 hard 1 soft 0 temp 1 loss 5.72 helix 1.05 pae 0.37 i_pae 0.48 con 2.40 i_con 3.27 plddt 0.72 ptm 0.61 i_ptm 0.64 rg 0.42
# 140 models [3] recycles 1 hard 1 soft 0 temp 1 loss 5.82 helix 0.98 pae 0.40 i_pae 0.50 con 2.43 i_con 3.28 plddt 0.72 ptm 0.61 i_ptm 0.61 rg 0.45
# Trajectory successful, final pLDDT: 0.86
# Starting trajectory took: 0 hours, 10 minutes, 37 seconds
#
# Fixing interface residues: B19,B21,B22,B25,B148
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn1, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn2, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn3, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn4, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn5, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn6, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn7, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn8, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn9, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn10, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn11, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn12, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn13, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn14, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn15, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn16, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn17, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn18, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn19, skipping interface scoring
# Base AF2 filters not passed for CTNI_l148_s125068_mpnn20, skipping interface scoring
# No accepted MPNN designs found for this trajectory.
# Design and validation of trajectory CTNI_l148_s125068 took: 0 hours, 1 minutes, 57 seconds
# Starting trajectory: CTNI_l87_s156510
# Stage 1: Test Logits
# 1 models [2] recycles 1 hard 0 soft 0.02 temp 1 loss 14.62 helix 1.09 pae 0.88 i_pae 0.94 con 4.88 i_con 5.05 plddt 0.38 ptm 0.38 i_ptm 0.08 rg 14.89
# 2 models [4] recycles 1 hard 0 soft 0.04 temp 1 loss 12.04 helix 0.77 pae 0.84 i_pae 0.91 con 4.95 i_con 4.84 plddt 0.40 ptm 0.40 i_ptm 0.10 rg 6.50
# 3 models [4] recycles 1 hard 0 soft 0.05 temp 1 loss 10.90 helix 0.76 pae 0.79 i_pae 0.89 con 4.07 i_con 4.70 plddt 0.44 ptm 0.37 i_ptm 0.12 rg 6.17
# 4 models [0] recycles 1 hard 0 soft 0.07 temp 1 loss 10.19 helix 0.92 pae 0.78 i_pae 0.86 con 4.06 i_con 4.68 plddt 0.38 ptm 0.40 i_ptm 0.17 rg 4.06
# 5 models [3] recycles 1 hard 0 soft 0.09 temp 1 loss 9.49 helix 0.86 pae 0.74 i_pae 0.83 con 3.96 i_con 4.39 plddt 0.41 ptm 0.43 i_ptm 0.18 rg 3.03
# 6 models [4] recycles 1 hard 0 soft 0.11 temp 1 loss 9.51 helix 0.67 pae 0.74 i_pae 0.86 con 3.75 i_con 4.50 plddt 0.46 ptm 0.41 i_ptm 0.16 rg 3.27
# 7 models [1] recycles 1 hard 0 soft 0.13 temp 1 loss 9.27 helix 0.75 pae 0.72 i_pae 0.81 con 3.81 i_con 4.35 plddt 0.42 ptm 0.41 i_ptm 0.23 rg 2.88
# ...
# 9 models [4] recycles 1 hard 0 soft 0.16 temp 1 loss 9.76 helix 0.69 pae 0.74 i_pae 0.93 con 3.36 i_con 5.37 plddt 0.55 ptm 0.32 i_ptm 0.10 rg 2.54
# 10 models [1] recycles 1 hard 0 soft 0.18 temp 1 loss 9.50 helix 0.83 pae 0.74 i_pae 0.93 con 3.42 i_con 5.29 plddt 0.51 ptm 0.31 i_ptm 0.10 rg 1.83
# 11 models [4] recycles 1 hard 0 soft 0.20 temp 1 loss 9.35 helix 0.79 pae 0.73 i_pae 0.91 con 3.44 i_con 5.06 plddt 0.52 ptm 0.32 i_ptm 0.12 rg 2.07
# 12 models [1] recycles 1 hard 0 soft 0.22 temp 1 loss 9.13 helix 0.79 pae 0.71 i_pae 0.90 con 3.24 i_con 5.04 plddt 0.54 ptm 0.33 i_ptm 0.13 rg 2.12
# 13 models [0] recycles 1 hard 0 soft 0.23 temp 1 loss 8.87 helix 0.83 pae 0.66 i_pae 0.91 con 2.74 i_con 5.30 plddt 0.65 ptm 0.34 i_ptm 0.12 rg 2.13
# 14 models [3] recycles 1 hard 0 soft 0.25 temp 1 loss 8.49 helix 0.88 pae 0.67 i_pae 0.88 con 2.99 i_con 4.81 plddt 0.60 ptm 0.35 i_ptm 0.16 rg 1.74
# 15 models [1] recycles 1 hard 0 soft 0.27 temp 1 loss 8.09 helix 0.90 pae 0.61 i_pae 0.86 con 2.54 i_con 4.76 plddt 0.68 ptm 0.39 i_ptm 0.17 rg 2.18
# 16 models [1] recycles 1 hard 0 soft 0.29 temp 1 loss 7.90 helix 0.96 pae 0.60 i_pae 0.85 con 2.39 i_con 4.72 plddt 0.72 ptm 0.40 i_ptm 0.19 rg 2.27
# 17 models [2] recycles 1 hard 0 soft 0.31 temp 1 loss 8.12 helix 0.86 pae 0.61 i_pae 0.85 con 2.50 i_con 4.73 plddt 0.69 ptm 0.39 i_ptm 0.19 rg 2.51
# 18 models [0] recycles 1 hard 0 soft 0.32 temp 1 loss 7.52 helix 0.95 pae 0.55 i_pae 0.77 con 2.32 i_con 4.42 plddt 0.68 ptm 0.43 i_ptm 0.26 rg 2.36
# 19 models [4] recycles 1 hard 0 soft 0.34 temp 1 loss 7.81 helix 0.94 pae 0.59 i_pae 0.85 con 2.26 i_con 4.73 plddt 0.73 ptm 0.40 i_ptm 0.18 rg 2.36
# 20 models [4] recycles 1 hard 0 soft 0.36 temp 1 loss 7.60 helix 0.98 pae 0.58 i_pae 0.82 con 2.29 i_con 4.52 plddt 0.72 ptm 0.41 i_ptm 0.21 rg 2.33
# 21 models [0] recycles 1 hard 0 soft 0.38 temp 1 loss 8.47 helix 0.93 pae 0.61 i_pae 0.82 con 2.89 i_con 4.84 plddt 0.63 ptm 0.38 i_ptm 0.23 rg 2.05
# 22 models [4] recycles 1 hard 0 soft 0.40 temp 1 loss 7.59 helix 0.96 pae 0.55 i_pae 0.78 con 2.33 i_con 4.46 plddt 0.74 ptm 0.43 i_ptm 0.30 rg 2.46
# 23 models [2] recycles 1 hard 0 soft 0.41 temp 1 loss 7.48 helix 0.97 pae 0.56 i_pae 0.81 con 2.20 i_con 4.48 plddt 0.78 ptm 0.43 i_ptm 0.24 rg 2.42
# 24 models [2] recycles 1 hard 0 soft 0.43 temp 1 loss 6.74 helix 1.07 pae 0.45 i_pae 0.66 con 2.01 i_con 4.02 plddt 0.83 ptm 0.51 i_ptm 0.42 rg 2.47
# 25 models [1] recycles 1 hard 0 soft 0.45 temp 1 loss 7.69 helix 1.07 pae 0.56 i_pae 0.82 con 2.20 i_con 4.68 plddt 0.75 ptm 0.43 i_ptm 0.25 rg 2.55
# 26 models [4] recycles 1 hard 0 soft 0.47 temp 1 loss 7.33 helix 1.10 pae 0.56 i_pae 0.84 con 1.93 i_con 4.63 plddt 0.83 ptm 0.44 i_ptm 0.20 rg 2.47
# 27 models [3] recycles 1 hard 0 soft 0.49 temp 1 loss 7.14 helix 1.17 pae 0.53 i_pae 0.78 con 2.04 i_con 4.40 plddt 0.81 ptm 0.44 i_ptm 0.30 rg 2.40
# 28 models [2] recycles 1 hard 0 soft 0.50 temp 1 loss 6.76 helix 1.11 pae 0.47 i_pae 0.69 con 2.02 i_con 4.05 plddt 0.83 ptm 0.50 i_ptm 0.39 rg 2.42
# 29 models [4] recycles 1 hard 0 soft 0.52 temp 1 loss 6.32 helix 1.21 pae 0.43 i_pae 0.62 con 1.88 i_con 3.75 plddt 0.84 ptm 0.55 i_ptm 0.51 rg 2.61
# 30 models [3] recycles 1 hard 0 soft 0.54 temp 1 loss 5.98 helix 1.24 pae 0.36 i_pae 0.51 con 1.99 i_con 3.37 plddt 0.85 ptm 0.61 i_ptm 0.70 rg 2.55
# 31 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 6.18 helix 1.26 pae 0.39 i_pae 0.56 con 2.03 i_con 3.54 plddt 0.84 ptm 0.56 i_ptm 0.62 rg 2.50
# 32 models [0] recycles 1 hard 0 soft 0.58 temp 1 loss 6.28 helix 1.20 pae 0.39 i_pae 0.56 con 2.04 i_con 3.59 plddt 0.82 ptm 0.56 i_ptm 0.63 rg 2.54
# 33 models [1] recycles 1 hard 0 soft 0.59 temp 1 loss 9.04 helix 0.92 pae 0.67 i_pae 0.90 con 3.07 i_con 5.20 plddt 0.58 ptm 0.31 i_ptm 0.12 rg 1.99
# 34 models [1] recycles 1 hard 0 soft 0.61 temp 1 loss 9.08 helix 0.92 pae 0.67 i_pae 0.91 con 3.01 i_con 5.19 plddt 0.60 ptm 0.31 i_ptm 0.12 rg 2.39
# 35 models [1] recycles 1 hard 0 soft 0.63 temp 1 loss 5.84 helix 1.26 pae 0.34 i_pae 0.47 con 2.09 i_con 3.07 plddt 0.83 ptm 0.65 i_ptm 0.81 rg 2.81
# 36 models [4] recycles 1 hard 0 soft 0.65 temp 1 loss 8.20 helix 1.00 pae 0.60 i_pae 0.85 con 2.47 i_con 4.86 plddt 0.71 ptm 0.37 i_ptm 0.18 rg 2.55
# 37 models [4] recycles 1 hard 0 soft 0.67 temp 1 loss 8.20 helix 1.01 pae 0.60 i_pae 0.87 con 2.45 i_con 4.90 plddt 0.72 ptm 0.38 i_ptm 0.16 rg 2.53
# 38 models [4] recycles 1 hard 0 soft 0.68 temp 1 loss 7.79 helix 1.11 pae 0.58 i_pae 0.85 con 2.21 i_con 4.72 plddt 0.77 ptm 0.41 i_ptm 0.18 rg 2.71
# 39 models [0] recycles 1 hard 0 soft 0.70 temp 1 loss 7.80 helix 1.09 pae 0.59 i_pae 0.79 con 2.41 i_con 4.56 plddt 0.68 ptm 0.40 i_ptm 0.25 rg 2.54
# 40 models [4] recycles 1 hard 0 soft 0.72 temp 1 loss 7.97 helix 0.95 pae 0.58 i_pae 0.83 con 2.47 i_con 4.62 plddt 0.71 ptm 0.40 i_ptm 0.20 rg 2.62
# 41 models [4] recycles 1 hard 0 soft 0.74 temp 1 loss 7.58 helix 1.08 pae 0.56 i_pae 0.83 con 2.07 i_con 4.62 plddt 0.80 ptm 0.43 i_ptm 0.21 rg 2.81
# 42 models [3] recycles 1 hard 0 soft 0.76 temp 1 loss 7.70 helix 1.11 pae 0.58 i_pae 0.87 con 2.05 i_con 4.79 plddt 0.82 ptm 0.42 i_ptm 0.15 rg 2.71
# 43 models [0] recycles 1 hard 0 soft 0.77 temp 1 loss 7.24 helix 0.91 pae 0.50 i_pae 0.69 con 2.37 i_con 3.96 plddt 0.74 ptm 0.49 i_ptm 0.50 rg 2.90
# 44 models [1] recycles 1 hard 0 soft 0.79 temp 1 loss 13.42 helix 0.76 pae 0.75 i_pae 0.82 con 3.97 i_con 4.57 plddt 0.50 ptm 0.39 i_ptm 0.24 rg 15.45
# 45 models [1] recycles 1 hard 0 soft 0.81 temp 1 loss 8.85 helix 0.82 pae 0.66 i_pae 0.84 con 3.21 i_con 4.73 plddt 0.56 ptm 0.36 i_ptm 0.19 rg 2.41
# 46 models [4] recycles 1 hard 0 soft 0.83 temp 1 loss 8.01 helix 0.85 pae 0.58 i_pae 0.82 con 2.46 i_con 4.59 plddt 0.71 ptm 0.41 i_ptm 0.24 rg 2.78
# 47 models [2] recycles 1 hard 0 soft 0.85 temp 1 loss 7.97 helix 0.86 pae 0.60 i_pae 0.84 con 2.45 i_con 4.63 plddt 0.72 ptm 0.39 i_ptm 0.19 rg 2.52
# 48 models [4] recycles 1 hard 0 soft 0.86 temp 1 loss 8.11 helix 0.90 pae 0.60 i_pae 0.83 con 2.63 i_con 4.64 plddt 0.68 ptm 0.38 i_ptm 0.23 rg 2.40
# 49 models [4] recycles 1 hard 0 soft 0.88 temp 1 loss 7.96 helix 0.90 pae 0.59 i_pae 0.83 con 2.35 i_con 4.73 plddt 0.74 ptm 0.41 i_ptm 0.20 rg 2.54
# 50 models [3] recycles 1 hard 0 soft 0.90 temp 1 loss 7.87 helix 0.83 pae 0.57 i_pae 0.77 con 2.68 i_con 4.31 plddt 0.67 ptm 0.43 i_ptm 0.28 rg 2.52
# Initial trajectory pLDDT good, continuing: 0.83
# Stage 1: Additional Logits Optimisation
# 51 models [0] recycles 1 hard 0 soft 0.04 temp 1 loss 7.87 helix 0.97 pae 0.58 i_pae 0.81 con 2.39 i_con 4.61 plddt 0.73 ptm 0.41 i_ptm 0.22 rg 2.60
# 52 models [3] recycles 1 hard 0 soft 0.08 temp 1 loss 7.91 helix 0.92 pae 0.58 i_pae 0.82 con 2.48 i_con 4.54 plddt 0.72 ptm 0.40 i_ptm 0.21 rg 2.61
# 53 models [2] recycles 1 hard 0 soft 0.12 temp 1 loss 6.83 helix 1.04 pae 0.50 i_pae 0.70 con 2.18 i_con 3.86 plddt 0.78 ptm 0.49 i_ptm 0.42 rg 2.60
# 54 models [2] recycles 1 hard 0 soft 0.16 temp 1 loss 8.97 helix 1.06 pae 0.74 i_pae 0.85 con 3.49 i_con 4.71 plddt 0.48 ptm 0.35 i_ptm 0.18 rg 2.03
# 55 models [1] recycles 1 hard 0 soft 0.20 temp 1 loss 7.40 helix 1.01 pae 0.52 i_pae 0.74 con 2.31 i_con 4.29 plddt 0.77 ptm 0.46 i_ptm 0.32 rg 2.57
# 56 models [4] recycles 1 hard 0 soft 0.24 temp 1 loss 6.55 helix 1.15 pae 0.46 i_pae 0.66 con 2.03 i_con 3.77 plddt 0.81 ptm 0.52 i_ptm 0.47 rg 2.66
# 57 models [4] recycles 1 hard 0 soft 0.28 temp 1 loss 6.27 helix 1.13 pae 0.43 i_pae 0.61 con 2.00 i_con 3.52 plddt 0.82 ptm 0.56 i_ptm 0.57 rg 2.72
# 58 models [1] recycles 1 hard 0 soft 0.32 temp 1 loss 7.06 helix 1.08 pae 0.52 i_pae 0.75 con 2.01 i_con 4.23 plddt 0.79 ptm 0.49 i_ptm 0.31 rg 2.70
# 59 models [1] recycles 1 hard 0 soft 0.36 temp 1 loss 6.91 helix 1.04 pae 0.48 i_pae 0.66 con 2.31 i_con 3.79 plddt 0.74 ptm 0.51 i_ptm 0.48 rg 2.73
# 60 models [4] recycles 1 hard 0 soft 0.40 temp 1 loss 5.87 helix 1.18 pae 0.39 i_pae 0.55 con 1.95 i_con 3.21 plddt 0.84 ptm 0.60 i_ptm 0.67 rg 2.71
# 61 models [4] recycles 1 hard 0 soft 0.44 temp 1 loss 6.08 helix 1.00 pae 0.40 i_pae 0.54 con 2.08 i_con 3.22 plddt 0.81 ptm 0.60 i_ptm 0.65 rg 2.75
# 62 models [1] recycles 1 hard 0 soft 0.48 temp 1 loss 5.98 helix 1.09 pae 0.39 i_pae 0.56 con 1.97 i_con 3.27 plddt 0.83 ptm 0.60 i_ptm 0.65 rg 2.75
# 63 models [0] recycles 1 hard 0 soft 0.52 temp 1 loss 8.84 helix 0.95 pae 0.67 i_pae 0.92 con 2.77 i_con 5.22 plddt 0.64 ptm 0.34 i_ptm 0.11 rg 2.34
# 64 models [0] recycles 1 hard 0 soft 0.56 temp 1 loss 6.09 helix 0.98 pae 0.42 i_pae 0.57 con 2.04 i_con 3.30 plddt 0.80 ptm 0.59 i_ptm 0.67 rg 2.62
# 65 models [4] recycles 1 hard 0 soft 0.60 temp 1 loss 6.44 helix 0.94 pae 0.43 i_pae 0.58 con 2.21 i_con 3.43 plddt 0.79 ptm 0.57 i_ptm 0.57 rg 2.73
# 66 models [3] recycles 1 hard 0 soft 0.64 temp 1 loss 6.77 helix 0.81 pae 0.46 i_pae 0.60 con 2.48 i_con 3.43 plddt 0.74 ptm 0.54 i_ptm 0.57 rg 2.70
# 67 models [0] recycles 1 hard 0 soft 0.68 temp 1 loss 6.25 helix 1.08 pae 0.43 i_pae 0.60 con 2.09 i_con 3.42 plddt 0.80 ptm 0.56 i_ptm 0.63 rg 2.64
# 68 models [4] recycles 1 hard 0 soft 0.72 temp 1 loss 5.88 helix 1.13 pae 0.40 i_pae 0.56 con 1.96 i_con 3.21 plddt 0.84 ptm 0.59 i_ptm 0.65 rg 2.68
# 69 models [1] recycles 1 hard 0 soft 0.76 temp 1 loss 9.17 helix 0.95 pae 0.76 i_pae 0.87 con 3.65 i_con 4.84 plddt 0.45 ptm 0.37 i_ptm 0.16 rg 1.58
# 70 models [0] recycles 1 hard 0 soft 0.80 temp 1 loss 8.86 helix 0.91 pae 0.69 i_pae 0.90 con 2.93 i_con 5.10 plddt 0.57 ptm 0.32 i_ptm 0.12 rg 2.18
# 71 models [0] recycles 1 hard 0 soft 0.84 temp 1 loss 7.15 helix 1.00 pae 0.50 i_pae 0.68 con 2.39 i_con 3.99 plddt 0.72 ptm 0.48 i_ptm 0.44 rg 2.52
# 72 models [2] recycles 1 hard 0 soft 0.88 temp 1 loss 7.88 helix 0.94 pae 0.58 i_pae 0.78 con 2.65 i_con 4.40 plddt 0.68 ptm 0.40 i_ptm 0.27 rg 2.43
# 73 models [3] recycles 1 hard 0 soft 0.92 temp 1 loss 6.85 helix 1.02 pae 0.50 i_pae 0.72 con 2.15 i_con 3.91 plddt 0.79 ptm 0.49 i_ptm 0.45 rg 2.59
# 74 models [4] recycles 1 hard 0 soft 0.96 temp 1 loss 6.33 helix 0.90 pae 0.43 i_pae 0.57 con 2.27 i_con 3.25 plddt 0.76 ptm 0.57 i_ptm 0.65 rg 2.69
# 75 models [0] recycles 1 hard 0 soft 1 temp 1 loss 7.63 helix 0.96 pae 0.53 i_pae 0.72 con 2.52 i_con 4.30 plddt 0.70 ptm 0.44 i_ptm 0.37 rg 2.53
# Optimised logit trajectory pLDDT: 0.84
# Stage 2: Softmax Optimisation
# 76 models [3] recycles 1 hard 0 soft 1 temp 0.96 loss 6.33 helix 1.00 pae 0.42 i_pae 0.58 con 2.25 i_con 3.31 plddt 0.79 ptm 0.56 i_ptm 0.65 rg 2.68
# 77 models [0] recycles 1 hard 0 soft 1 temp 0.91 loss 5.81 helix 1.15 pae 0.38 i_pae 0.51 con 2.06 i_con 3.05 plddt 0.81 ptm 0.62 i_ptm 0.74 rg 2.72
# 78 models [2] recycles 1 hard 0 soft 1 temp 0.87 loss 7.86 helix 0.98 pae 0.60 i_pae 0.86 con 2.25 i_con 4.78 plddt 0.76 ptm 0.40 i_ptm 0.17 rg 2.46
# 79 models [4] recycles 1 hard 0 soft 1 temp 0.83 loss 6.54 helix 0.96 pae 0.46 i_pae 0.63 con 2.20 i_con 3.59 plddt 0.78 ptm 0.54 i_ptm 0.51 rg 2.51
# 80 models [4] recycles 1 hard 0 soft 1 temp 0.79 loss 6.34 helix 1.02 pae 0.43 i_pae 0.60 con 2.12 i_con 3.45 plddt 0.80 ptm 0.56 i_ptm 0.58 rg 2.66
# 81 models [1] recycles 1 hard 0 soft 1 temp 0.75 loss 6.03 helix 1.12 pae 0.43 i_pae 0.60 con 1.98 i_con 3.31 plddt 0.81 ptm 0.58 i_ptm 0.65 rg 2.67
# 82 models [2] recycles 1 hard 0 soft 1 temp 0.72 loss 6.01 helix 1.05 pae 0.43 i_pae 0.59 con 2.03 i_con 3.21 plddt 0.81 ptm 0.58 i_ptm 0.65 rg 2.74
# 83 models [2] recycles 1 hard 0 soft 1 temp 0.68 loss 6.11 helix 1.07 pae 0.43 i_pae 0.59 con 2.06 i_con 3.25 plddt 0.81 ptm 0.58 i_ptm 0.65 rg 2.84
# 84 models [0] recycles 1 hard 0 soft 1 temp 0.64 loss 6.04 helix 1.07 pae 0.42 i_pae 0.58 con 2.03 i_con 3.24 plddt 0.81 ptm 0.58 i_ptm 0.68 rg 2.79
# 85 models [3] recycles 1 hard 0 soft 1 temp 0.61 loss 6.28 helix 1.16 pae 0.42 i_pae 0.55 con 2.29 i_con 3.28 plddt 0.77 ptm 0.58 i_ptm 0.65 rg 2.66
# 86 models [4] recycles 1 hard 0 soft 1 temp 0.58 loss 6.04 helix 1.19 pae 0.40 i_pae 0.55 con 2.09 i_con 3.22 plddt 0.82 ptm 0.59 i_ptm 0.70 rg 2.80
# 87 models [2] recycles 1 hard 0 soft 1 temp 0.54 loss 5.61 helix 1.15 pae 0.39 i_pae 0.54 con 1.92 i_con 2.98 plddt 0.85 ptm 0.62 i_ptm 0.76 rg 2.73
# 88 models [4] recycles 1 hard 0 soft 1 temp 0.51 loss 6.14 helix 1.07 pae 0.42 i_pae 0.58 con 2.10 i_con 3.25 plddt 0.82 ptm 0.58 i_ptm 0.62 rg 2.84
# 89 models [1] recycles 1 hard 0 soft 1 temp 0.48 loss 7.25 helix 1.02 pae 0.51 i_pae 0.65 con 2.78 i_con 3.75 plddt 0.67 ptm 0.51 i_ptm 0.54 rg 2.35
# 90 models [1] recycles 1 hard 0 soft 1 temp 0.45 loss 5.54 helix 1.19 pae 0.38 i_pae 0.53 con 1.86 i_con 2.96 plddt 0.85 ptm 0.62 i_ptm 0.71 rg 2.82
# 91 models [4] recycles 1 hard 0 soft 1 temp 0.42 loss 5.78 helix 1.08 pae 0.38 i_pae 0.52 con 2.03 i_con 3.00 plddt 0.83 ptm 0.62 i_ptm 0.70 rg 2.77
# 92 models [3] recycles 1 hard 0 soft 1 temp 0.39 loss 6.05 helix 0.99 pae 0.42 i_pae 0.57 con 2.08 i_con 3.20 plddt 0.82 ptm 0.58 i_ptm 0.65 rg 2.71
# 93 models [3] recycles 1 hard 0 soft 1 temp 0.37 loss 5.33 helix 1.31 pae 0.36 i_pae 0.51 con 1.82 i_con 2.85 plddt 0.88 ptm 0.63 i_ptm 0.75 rg 2.76
# 94 models [4] recycles 1 hard 0 soft 1 temp 0.34 loss 5.54 helix 1.09 pae 0.37 i_pae 0.50 con 1.97 i_con 2.84 plddt 0.84 ptm 0.64 i_ptm 0.75 rg 2.79
# 95 models [1] recycles 1 hard 0 soft 1 temp 0.32 loss 5.59 helix 1.09 pae 0.39 i_pae 0.53 con 1.99 i_con 2.88 plddt 0.82 ptm 0.62 i_ptm 0.76 rg 2.69
# 96 models [1] recycles 1 hard 0 soft 1 temp 0.29 loss 5.84 helix 1.29 pae 0.41 i_pae 0.59 con 1.91 i_con 3.24 plddt 0.85 ptm 0.59 i_ptm 0.67 rg 2.77
# 97 models [3] recycles 1 hard 0 soft 1 temp 0.27 loss 6.90 helix 1.10 pae 0.49 i_pae 0.65 con 2.34 i_con 3.82 plddt 0.75 ptm 0.51 i_ptm 0.46 rg 2.50
# 98 models [0] recycles 1 hard 0 soft 1 temp 0.25 loss 5.96 helix 1.05 pae 0.39 i_pae 0.52 con 2.11 i_con 3.10 plddt 0.80 ptm 0.60 i_ptm 0.72 rg 2.75
# 99 models [4] recycles 1 hard 0 soft 1 temp 0.23 loss 5.69 helix 1.17 pae 0.38 i_pae 0.52 con 2.01 i_con 2.97 plddt 0.84 ptm 0.62 i_ptm 0.74 rg 2.80
# 100 models [1] recycles 1 hard 0 soft 1 temp 0.21 loss 5.81 helix 1.28 pae 0.39 i_pae 0.54 con 2.06 i_con 3.07 plddt 0.81 ptm 0.60 i_ptm 0.71 rg 2.75
# 101 models [1] recycles 1 hard 0 soft 1 temp 0.19 loss 6.02 helix 1.29 pae 0.40 i_pae 0.55 con 2.17 i_con 3.18 plddt 0.80 ptm 0.59 i_ptm 0.69 rg 2.66
# 102 models [3] recycles 1 hard 0 soft 1 temp 0.17 loss 5.83 helix 1.16 pae 0.40 i_pae 0.55 con 2.04 i_con 3.06 plddt 0.84 ptm 0.60 i_ptm 0.69 rg 2.77
# 103 models [0] recycles 1 hard 0 soft 1 temp 0.15 loss 5.60 helix 1.18 pae 0.36 i_pae 0.48 con 2.05 i_con 2.89 plddt 0.84 ptm 0.64 i_ptm 0.76 rg 2.67
# 104 models [1] recycles 1 hard 0 soft 1 temp 0.14 loss 5.72 helix 1.15 pae 0.37 i_pae 0.49 con 2.09 i_con 2.93 plddt 0.82 ptm 0.63 i_ptm 0.72 rg 2.73
# 105 models [4] recycles 1 hard 0 soft 1 temp 0.12 loss 6.23 helix 1.15 pae 0.40 i_pae 0.52 con 2.35 i_con 3.13 plddt 0.77 ptm 0.59 i_ptm 0.68 rg 2.81
# 106 models [0] recycles 1 hard 0 soft 1 temp 0.11 loss 5.40 helix 1.13 pae 0.34 i_pae 0.45 con 2.00 i_con 2.74 plddt 0.84 ptm 0.66 i_ptm 0.78 rg 2.65
# 107 models [0] recycles 1 hard 0 soft 1 temp 0.09 loss 5.48 helix 1.18 pae 0.35 i_pae 0.47 con 2.03 i_con 2.79 plddt 0.84 ptm 0.64 i_ptm 0.78 rg 2.67
# 108 models [1] recycles 1 hard 0 soft 1 temp 0.08 loss 5.62 helix 1.26 pae 0.37 i_pae 0.51 con 1.98 i_con 2.94 plddt 0.85 ptm 0.62 i_ptm 0.72 rg 2.85
# 109 models [2] recycles 1 hard 0 soft 1 temp 0.07 loss 5.54 helix 1.21 pae 0.36 i_pae 0.49 con 2.03 i_con 2.81 plddt 0.85 ptm 0.64 i_ptm 0.75 rg 2.79
# 110 models [3] recycles 1 hard 0 soft 1 temp 0.06 loss 5.47 helix 1.24 pae 0.36 i_pae 0.49 con 1.97 i_con 2.81 plddt 0.86 ptm 0.64 i_ptm 0.75 rg 2.78
# 111 models [2] recycles 1 hard 0 soft 1 temp 0.05 loss 5.91 helix 1.13 pae 0.39 i_pae 0.52 con 2.17 i_con 3.02 plddt 0.82 ptm 0.61 i_ptm 0.71 rg 2.75
# 112 models [1] recycles 1 hard 0 soft 1 temp 0.04 loss 5.31 helix 1.25 pae 0.35 i_pae 0.49 con 1.91 i_con 2.75 plddt 0.86 ptm 0.65 i_ptm 0.77 rg 2.68
# 113 models [2] recycles 1 hard 0 soft 1 temp 0.03 loss 6.15 helix 1.23 pae 0.41 i_pae 0.53 con 2.29 i_con 3.22 plddt 0.79 ptm 0.58 i_ptm 0.64 rg 2.51
# 114 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 9.48 helix 1.07 pae 0.75 i_pae 0.93 con 3.26 i_con 5.32 plddt 0.49 ptm 0.33 i_ptm 0.10 rg 2.47

# %%
#@title Consolidate & Rank Designs
#@markdown ---
accepted_binders = [f for f in os.listdir(design_paths["Accepted"]) if f.endswith('.pdb')]

for f in os.listdir(design_paths["Accepted/Ranked"]):
    os.remove(os.path.join(design_paths["Accepted/Ranked"], f))

# load dataframe of designed binders
design_df = pd.read_csv(mpnn_csv)
design_df = design_df.sort_values('Average_i_pTM', ascending=False)

# create final csv dataframe to copy matched rows, initialize with the column labels
final_df = pd.DataFrame(columns=final_labels)

# check the ranking of the designs and copy them with new ranked IDs to the folder
rank = 1
for _, row in design_df.iterrows():
    for binder in accepted_binders:
        target_settings["binder_name"], model = binder.rsplit('_model', 1)
        if target_settings["binder_name"] == row['Design']:
            # rank and copy into ranked folder
            row_data = {'Rank': rank, **{label: row[label] for label in design_labels}}
            final_df = pd.concat([final_df, pd.DataFrame([row_data])], ignore_index=True)
            old_path = os.path.join(design_paths["Accepted"], binder)
            new_path = os.path.join(design_paths["Accepted/Ranked"], f"{rank}_{target_settings['binder_name']}_model{model.rsplit('.', 1)[0]}.pdb")
            shutil.copyfile(old_path, new_path)

            rank += 1
            break

# save the final_df to final_csv
final_df.to_csv(final_csv, index=False)

print("Designs ranked and final_designs_stats.csv generated")

# %%
#@title Top 20 Designs
df = pd.read_csv(os.path.join(design_path, 'final_design_stats.csv'))
df.head(20)

# %%
#@title Top Design Display
import py3Dmol
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

# Visualise in PyMOL
view = py3Dmol.view()
view.addModel(open(top_design_pdb, 'r').read(),'pdb')
view.setBackgroundColor('white')
view.setStyle({'chain':'A'}, {'cartoon': {'color':'#3c5b6f'}})
view.setStyle({'chain':'B'}, {'cartoon': {'color':'#B76E79'}})
view.zoomTo()
view.show()

# %%
#@title Display animation
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

top_design_name = os.path.basename(top_design_pdb).split('1_', 1)[1].split('_mpnn')[0]
top_design_animation = os.path.join(design_path, 'Accepted', 'Animation', f"{top_design_name}.html")

# Show animation
HTML(top_design_animation)
